# %% [markdown]
# ### Imports

# %%
import random
import nltk
import csv
from nltk.corpus import stopwords
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()

# %% [markdown]
# ### Read in the Train and Test .tsv from the directory

# %%
train = open("final_train.tsv", 'r')

# %%
test = open("final_test.tsv", 'r')

# %% [markdown]
# ## Start cleaning the data

# %%
# loop over lines in the file and use the first limit of them
phrasedata = []
for x in train:
    # ignore the first line starting with Phrase and read all lines
    if (not x.startswith('Phrase')):
        x = x.strip()
        phrasedata.append(x.split('\t')[2:4])

# %%
phrasedata[:15]
# Out:
# [['A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .',
#   '1'],
#  ['A series of escapades demonstrating the adage that what is good for the goose',
#   '2'],
#  ['A series', '2'],
#  ['A', '2'],
#  ['series', '2'],
#  ['of escapades demonstrating the adage that what is good for the goose', '2'],
#  ['of', '2'],
#  ['escapades demonstrating the adage that what is good for the goose', '2'],
#  ['escapades', '2'],
#  ['demonstrating the adage that what is good for the goose', '2'],
#  ['demonstrating the adage', '2'],
#  ['demonstrating', '2'],
#  ['the adage', '2'],
#  ['the', '2'],
#  ['adage', '2']]

# %%
 # pick a random sample of length limit because of phrase overlapping sequences
random.shuffle(phrasedata)
phraselist = phrasedata[:5000]

# %%
print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
# Out:
# Read 156060 phrases, using 5000 random phrases

# %% [markdown]
# ## Tokenize and Lower

# %%
# create list of phrase documents as (list of words, label)
phrasedocs = []

# add all the phrases

# each phrase has a list of tokens and the sentiment label (from 0 to 4)
# bin to only 3 categories for better performance
for phrase in phraselist:
    tokens = nltk.word_tokenize(phrase[0])
    phrasedocs.append((tokens, int(phrase[1])))

# %%
# lowercase - each phrase is a pair consisting of a token list and a label
docs = []
for phrase in phrasedocs:
    lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
    docs.append (lowerphrase)
# print a few
for phrase in docs[:10]:
    print (phrase)
# Out:
# (['the', 'boys', "'"], 2)
# (['turbulent', 'times'], 2)
# (['pandering'], 1)
# (['of', 'the', 'year'], 2)
# (['while', 'somewhat', 'less', 'than', 'it', 'might', 'have', 'been', ',', 'the', 'film', 'is', 'a', 'good', 'one', ',', 'and', 'you', "'ve", 'got', 'to', 'hand', 'it', 'to', 'director', 'george', 'clooney', 'for', 'biting', 'off', 'such', 'a', 'big', 'job', 'the', 'first', 'time', 'out', '.'], 3)
# (['that', 'would', 'make', 'this', 'a', 'moving', 'experience', 'for', 'people', 'who', 'have', "n't", 'read', 'the', 'book'], 3)
# (["'s", 'a', 'sharp', 'movie', 'about', 'otherwise', 'dull', 'subjects'], 3)
# (['flaws', ',', 'but', 'also', 'stretches', 'of', 'impact', 'and', 'moments', 'of', 'awe'], 2)
# (['you', "'re", 'depressed', 'about', 'anything', 'before', 'watching', 'this', 'film'], 2)
# (['plot-lines'], 2)

# %% [markdown]
# ## Create a list of words and word features

# %%
# continue as usual to get all words and create word features
all_words_list = [word for (sent,cat) in docs for word in sent]
all_words = nltk.FreqDist(all_words_list)
print(len(all_words))
# Out:
# 7379

# %%
# get the 1500 most frequently appearing keywords in the corpus
word_items = all_words.most_common(1500)
word_features = [word for (word,count) in word_items]

# %%
for x in word_items[:25]:
    print(x[0], "\t", x[1])
# Out:
# the 	 1573
# , 	 1302
# a 	 1113
# and 	 1049
# of 	 1029
# to 	 690
# . 	 551
# 's 	 504
# is 	 441
# in 	 417
# that 	 391
# it 	 369
# as 	 272
# with 	 253
# for 	 241
# its 	 233
# an 	 206
# film 	 190
# movie 	 190
# you 	 172
# but 	 170
# this 	 167
# on 	 155
# be 	 145
# his 	 125

# %% [markdown]
# ## Create stopword list and remove stopwords

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
stopwords.extend([',', '.',"'s", "'", '--', '``', '...', '`', '-rrb-', '-lrb-', ':'])

# %%
negationwords = ['no', 'not', 'never', 'none', 'nowhere', 'nothing', 'noone', 'rather', 'hardly', 'scarcely', 'rarely', 'seldom', 'neither', 'nor']

# %%
negationwords.extend(['ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn'])

# %%
newstopwords = [word for word in stopwords if word not in negationwords]
new_all_words_list = [word for (sent,cat) in docs for word in sent if word not in newstopwords]

# %% [markdown]
# ## Create new wordlist and features with the stopwords removed

# %%
# continue to define a new all words dictionary, get the 1500 most common as new_word_features
new_all_words = nltk.FreqDist(new_all_words_list)
new_word_items = new_all_words.most_common(1500)

# %%
new_word_features = [word for (word,count) in new_word_items]

# %%
for x in new_word_items[:25]:
    print(x[0], "\t\t", x[1])
# Out:
# film 		 190
# movie 		 190
# not 		 113
# n't 		 106
# like 		 103
# one 		 102
# story 		 73
# comedy 		 62
# much 		 62
# good 		 61
# characters 		 60
# time 		 54
# funny 		 54
# make 		 53
# love 		 49
# even 		 49
# never 		 48
# us 		 48
# way 		 46
# work 		 46
# no 		 44
# little 		 43
# audience 		 40
# enough 		 39
# movies 		 39

# %% [markdown]
# ## Create Bigram Features

# %%
finder = BigramCollocationFinder.from_words(all_words_list)
bigram_features = finder.nbest(bigram_measures.chi_sq, 500)

# %% [markdown]
# ## Document Features Function

# %%
def document_features(document, word_features):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = (word in document_words)
    return features

# %% [markdown]
# ## Negation Features Function

# %%
def NOT_features(document, word_features, negationwords):
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = False
        features['V_NOT{}'.format(word)] = False
    # go through document words in order
    for i in range(0, len(document)):
        word = document[i]
        if ((i + 1) < len(document)) and ((word in negationwords) or (word.endswith("n't"))):
            i += 1
            features['V_NOT{}'.format(document[i])] = (document[i] in word_features)
        else:
            features['V_{}'.format(word)] = (word in word_features)
    return features

# %% [markdown]
# ## Part of Speech Features Function

# %%
def POS_features(document, word_features):
    document_words = set(document)
    tagged_words = nltk.pos_tag(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    numNoun = 0
    numVerb = 0
    numAdj = 0
    numAdverb = 0
    for (word, tag) in tagged_words:
        if tag.startswith('N'): numNoun += 1
        if tag.startswith('V'): numVerb += 1
        if tag.startswith('J'): numAdj += 1
        if tag.startswith('R'): numAdverb += 1
    features['nouns'] = numNoun
    features['verbs'] = numVerb
    features['adjectives'] = numAdj
    features['adverbs'] = numAdverb
    return features

# %% [markdown]
# ## Cross Validation Function

# %%
def cross_validation_PRF(num_folds, featuresets, labels):
    subset_size = int(len(featuresets)/num_folds)
    print('Each fold size:', subset_size)
    # for the number of labels - start the totals lists with zeroes
    num_labels = len(labels)
    total_precision_list = [0] * num_labels
    total_recall_list = [0] * num_labels
    total_F1_list = [0] * num_labels

    # iterate over the folds
    for i in range(num_folds):
        test_this_round = featuresets[(i*subset_size):][:subset_size]
        train_this_round = featuresets[:(i*subset_size)] + featuresets[((i+1)*subset_size):]
        # train using train_this_round
        classifier = nltk.NaiveBayesClassifier.train(train_this_round)
        # evaluate against test_this_round to produce the gold and predicted labels
        goldlist = []
        predictedlist = []
        for (features, label) in test_this_round:
            goldlist.append(label)
            predictedlist.append(classifier.classify(features))

        # computes evaluation measures for this fold and
        #   returns list of measures for each label
        print('Fold', i)
        (precision_list, recall_list, F1_list) \
                  = eval_measures(goldlist, predictedlist, labels)
        for i in range(num_labels):
            # for each label, add the 3 measures to the 3 lists of totals
            total_precision_list[i] += precision_list[i]
            total_recall_list[i] += recall_list[i]
            total_F1_list[i] += F1_list[i]

    # find precision, recall and F measure averaged over all rounds for all labels
    # compute averages from the totals lists
    precision_list = [tot/num_folds for tot in total_precision_list]
    recall_list = [tot/num_folds for tot in total_recall_list]
    F1_list = [tot/num_folds for tot in total_F1_list]
    # the evaluation measures in a table with one row per label
    print('\nAverage Precision\tRecall\t\tF1 \tPer Label')
    # print measures for each label
    for i, lab in enumerate(labels):
        print(lab, '\t', "{:10.3f}".format(precision_list[i]), \
          "{:10.3f}".format(recall_list[i]), "{:10.3f}".format(F1_list[i]))
    
    # print macro average over all labels - treats each label equally
    print('\nMacro Average Precision\tRecall\t\tF1 \tOver All Labels')
    print('\t', "{:10.3f}".format(sum(precision_list)/num_labels), \
          "{:10.3f}".format(sum(recall_list)/num_labels), \
          "{:10.3f}".format(sum(F1_list)/num_labels))

    # for micro averaging, weight the scores for each label by the number of items
    #    this is better for labels with imbalance
    # first intialize a dictionary for label counts and then count them
    label_counts = {}
    for lab in labels:
      label_counts[lab] = 0 
    # count the labels
    for (doc, lab) in featuresets:
      label_counts[lab] += 1
    # make weights compared to the number of documents in featuresets
    num_docs = len(featuresets)
    label_weights = [(label_counts[lab] / num_docs) for lab in labels]
    print('\nLabel Counts', label_counts)
    #print('Label weights', label_weights)
    # print macro average over all labels
    print('Micro Average Precision\tRecall\t\tF1 \tOver All Labels')
    precision = sum([a * b for a,b in zip(precision_list, label_weights)])
    recall = sum([a * b for a,b in zip(recall_list, label_weights)])
    F1 = sum([a * b for a,b in zip(F1_list, label_weights)])
    print( '\t', "{:10.3f}".format(precision), \
      "{:10.3f}".format(recall), "{:10.3f}".format(F1))

# %% [markdown]
# ## Evaluation Measures Function

# %%
def eval_measures(gold, predicted, labels):
    
    # these lists have values for each label 
    recall_list = []
    precision_list = []
    F1_list = []

    for lab in labels:
        # for each label, compare gold and predicted lists and compute values
        TP = FP = FN = TN = 0
        for i, val in enumerate(gold):
            if val == lab and predicted[i] == lab:  TP += 1
            if val == lab and predicted[i] != lab:  FN += 1
            if val != lab and predicted[i] == lab:  FP += 1
            if val != lab and predicted[i] != lab:  TN += 1
        # use these to compute recall, precision, F1
        # for small numbers, guard against dividing by zero in computing measures
        if (TP == 0) or (FP == 0) or (FN == 0):
          recall_list.append (0)
          precision_list.append (0)
          F1_list.append(0)
        else:
          recall = TP / (TP + FP)
          precision = TP / (TP + FN)
          recall_list.append(recall)
          precision_list.append(precision)
          F1_list.append( 2 * (recall * precision) / (recall + precision))

    # the evaluation measures in a table with one row per label
    return (precision_list, recall_list, F1_list)

# %% [markdown]
# ## Bigram Document Features Function

# %%
def bigram_document_features(document, word_features, bigram_features):
    document_words = set(document)
    document_bigrams = nltk.bigrams(document)
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = (word in document_words)
    for bigram in bigram_features:
        features['B_{}_{}'.format(bigram[0], bigram[1])] = (bigram in document_bigrams)    
    return features

# %%
  # feature sets from feature definition functions above
featuresets = [(document_features(d, word_features), c) for (d, c) in docs]
negfeaturesets = [(NOT_features(d, word_features, negationwords), c) for (d, c) in docs]
bigramfeaturesets = [(bigram_document_features(d, word_features, bigram_features), c) for (d, c) in docs]
POSfeaturesets = [(POS_features(d, new_word_features), c) for (d, c) in docs]
# train classifier and show performance in cross-validation
# make a list of labels
label_list = [c for (d,c) in docs]
labels = list(set(label_list))    # gets only unique labels
num_folds = 10

# %%
featuresets[:1]
# Out:
# [({'V_the': True,
#    'V_,': False,
#    'V_a': False,
#    'V_and': False,
#    'V_of': False,
#    'V_to': False,
#    'V_.': False,
#    "V_'s": False,
#    'V_is': False,
#    'V_in': False,
#    'V_that': False,
#    'V_it': False,
#    'V_as': False,
#    'V_with': False,
#    'V_for': False,
#    'V_its': False,
#    'V_an': False,
#    'V_film': False,
#    'V_movie': False,
#    'V_you': False,
#    'V_but': False,
#    'V_this': False,
#    'V_on': False,
#    'V_be': False,
#    'V_his': False,
#    'V_more': False,
#    'V_has': False,
#    'V_--': False,
#    'V_by': False,
#    'V_not': False,
#    'V_than': False,
#    'V_at': False,
#    "V_n't": False,
#    "V_'": True,
#    'V_all': False,
#    'V_like': False,
#    'V_one': False,
#    'V_about': False,
#    'V_or': False,
#    'V_from': False,
#    'V_have': False,
#    'V_``': False,
#    'V_are': False,
#    'V_-rrb-': False,
#    'V_so': False,
#    'V_most': False,
#    'V_-lrb-': False,
#    'V_`': False,
#    'V_story': False,
#    'V_out': False,
#    'V_their': False,
#    'V_comedy': False,
#    'V_much': False,
#    'V_good': False,
#    'V_your': False,
#    'V_into': False,
#    'V_who': False,
#    'V_characters': False,
#    'V_up': False,
#    'V_just': False,
#    'V_does': False,
#    'V_time': False,
#    'V_funny': False,
#    'V_make': False,
#    'V_can': False,
#    'V_what': False,
#    'V_own': False,
#    'V_any': False,
#    'V_some': False,
#    'V_i': False,
#    'V_will': False,
#    'V_if': False,
#    'V_love': False,
#    'V_even': False,
#    'V_never': False,
#    'V_us': False,
#    'V_was': False,
#    'V_too': False,
#    'V_way': False,
#    'V_work': False,
#    'V_which': False,
#    'V_been': False,
#    'V_no': False,
#    'V_only': False,
#    'V_very': False,
#    'V_...': False,
#    'V_little': False,
#    'V_her': False,
#    'V_he': False,
#    'V_audience': False,
#    'V_enough': False,
#    'V_movies': False,
#    'V_director': False,
#    'V_people': False,
#    'V_films': False,
#    'V_plot': False,
#    'V_could': False,
#    'V_life': False,
#    'V_new': False,
#    'V_something': False,
#    'V_off': False,
#    'V_action': False,
#    'V_they': False,
#    'V_through': False,
#    'V_we': False,
#    'V_while': False,
#    'V_many': False,
#    'V_these': False,
#    'V_real': False,
#    'V_see': False,
#    'V_those': False,
#    'V_there': False,
#    'V_bad': False,
#    'V_less': False,
#    'V_hollywood': False,
#    'V_when': False,
#    'V_two': False,
#    'V_such': False,
#    'V_without': False,
#    'V_minutes': False,
#    'V_drama': False,
#    'V_how': False,
#    'V_also': False,
#    'V_man': False,
#    'V_long': False,
#    'V_should': False,
#    'V_better': False,
#    'V_big': False,
#    'V_made': False,
#    'V_makes': False,
#    'V_may': False,
#    "V_'ve": False,
#    'V_well': False,
#    'V_seen': False,
#    'V_ever': False,
#    'V_few': False,
#    'V_down': False,
#    'V_character': False,
#    'V_do': False,
#    'V_other': False,
#    'V_kind': False,
#    'V_would': False,
#    'V_feel': False,
#    'V_another': False,
#    'V_between': False,
#    'V_bit': False,
#    'V_cast': False,
#    'V_humor': False,
#    'V_heart': False,
#    'V_best': False,
#    'V_them': False,
#    'V_young': False,
#    'V_every': False,
#    'V_really': False,
#    'V_being': False,
#    'V_right': False,
#    'V_interesting': False,
#    'V_look': False,
#    "V_'re": False,
#    'V_american': False,
#    'V_sense': False,
#    'V_war': False,
#    'V_great': False,
#    'V_after': False,
#    'V_get': False,
#    'V_world': False,
#    'V_watching': False,
#    'V_emotional': False,
#    'V_away': False,
#    'V_:': False,
#    'V_take': False,
#    'V_almost': False,
#    'V_family': False,
#    'V_fun': False,
#    'V_me': False,
#    'V_quite': False,
#    'V_both': False,
#    'V_nothing': False,
#    'V_human': False,
#    'V_screen': False,
#    'V_far': False,
#    'V_entertaining': False,
#    'V_tale': False,
#    'V_feels': False,
#    'V_had': False,
#    'V_original': False,
#    'V_want': False,
#    'V_acting': False,
#    'V_our': False,
#    'V_often': False,
#    'V_thriller': False,
#    'V_performances': False,
#    'V_dialogue': False,
#    'V_give': False,
#    'V_around': False,
#    'V_might': False,
#    'V_over': False,
#    'V_dramatic': False,
#    'V_same': False,
#    'V_my': False,
#    'V_comic': False,
#    'V_subject': False,
#    'V_watch': False,
#    'V_were': False,
#    'V_material': False,
#    'V_itself': False,
#    'V_entertainment': False,
#    'V_worst': False,
#    'V_think': False,
#    'V_performance': False,
#    'V_together': False,
#    'V_hard': False,
#    'V_making': False,
#    'V_rather': False,
#    'V_matter': False,
#    'V_year': False,
#    'V_first': False,
#    'V_moments': False,
#    'V_anything': False,
#    'V_where': False,
#    'V_familiar': False,
#    'V_need': False,
#    'V_women': False,
#    'V_surprisingly': False,
#    'V_come': False,
#    'V_find': False,
#    'V_laughs': False,
#    'V_once': False,
#    'V_things': False,
#    'V_point': False,
#    'V_compelling': False,
#    'V_;': False,
#    'V_fans': False,
#    'V_next': False,
#    'V_\\': False,
#    'V_*': False,
#    'V_show': False,
#    'V_script': False,
#    'V_pretty': False,
#    'V_last': False,
#    'V_full': False,
#    'V_star': False,
#    'V_back': False,
#    'V_go': False,
#    'V_cinema': False,
#    'V_ca': False,
#    'V_pure': False,
#    'V_camera': False,
#    'V_dark': False,
#    'V_music': False,
#    'V_children': False,
#    'V_sweet': False,
#    'V_takes': False,
#    'V_line': False,
#    'V_head': False,
#    'V_under': False,
#    'V_still': False,
#    'V_comes': False,
#    'V_three': False,
#    'V_video': False,
#    'V_actors': False,
#    'V_old': False,
#    'V_here': False,
#    'V_because': False,
#    'V_she': False,
#    'V_end': False,
#    'V_then': False,
#    'V_thing': False,
#    'V_times': False,
#    'V_book': False,
#    'V_keep': False,
#    'V_day': False,
#    'V_going': False,
#    'V_anyone': False,
#    'V_charming': False,
#    'V_premise': False,
#    'V_-': False,
#    'V_him': False,
#    'V_lives': False,
#    'V_scenes': False,
#    'V_summer': False,
#    'V_romantic': False,
#    'V_works': False,
#    'V_beautiful': False,
#    'V_short': False,
#    'V_cinematic': False,
#    'V_ultimately': False,
#    'V_history': False,
#    'V_picture': False,
#    'V_sometimes': False,
#    'V_genre': False,
#    'V_years': False,
#    'V_flick': False,
#    'V_himself': False,
#    'V_before': False,
#    'V_style': False,
#    'V_charm': False,
#    'V_visual': False,
#    'V_gentle': False,
#    'V_true': False,
#    'V_special': False,
#    'V_spirit': False,
#    'V_against': False,
#    'V_feeling': False,
#    'V_predictable': False,
#    'V_ride': False,
#    'V_social': False,
#    'V_face': False,
#    'V_power': False,
#    'V_past': False,
#    'V_filmmaking': False,
#    'V_wit': False,
#    'V_hour': False,
#    'V_goes': False,
#    'V_amusing': False,
#    'V_half': False,
#    'V_portrait': False,
#    'V_set': False,
#    'V_moving': False,
#    'V_experience': False,
#    'V_ambitious': False,
#    'V_place': False,
#    'V_nearly': False,
#    'V_trying': False,
#    'V_now': False,
#    'V_title': False,
#    'V_especially': False,
#    'V_surprise': False,
#    'V_series': False,
#    'V_everyone': False,
#    'V_black': False,
#    'V_horror': False,
#    'V_become': False,
#    'V_classic': False,
#    'V_adventure': False,
#    'V_least': False,
#    'V_documentary': False,
#    'V_french': False,
#    'V_lot': False,
#    'V_gives': False,
#    'V_days': False,
#    'V_idea': False,
#    'V_satisfying': False,
#    'V_yet': False,
#    'V_seem': False,
#    'V_engaging': False,
#    'V_images': False,
#    'V_boy': False,
#    'V_perfect': False,
#    'V_exercise': False,
#    'V_worth': False,
#    'V_directed': False,
#    'V_fascinating': False,
#    'V_energy': False,
#    'V_small': False,
#    'V_warmth': False,
#    'V_ways': False,
#    'V_change': False,
#    'V_shot': False,
#    'V_animation': False,
#    'V_creative': False,
#    'V_usual': False,
#    'V_events': False,
#    'V_remains': False,
#    'V_leave': False,
#    'V_theater': False,
#    'V_stories': False,
#    'V_completely': False,
#    'V_truly': False,
#    'V_know': False,
#    'V_tell': False,
#    'V_epic': False,
#    'V_rich': False,
#    'V_suspense': False,
#    'V_audiences': False,
#    'V_crime': False,
#    "V_'ll": False,
#    'V_silly': False,
#    'V_guys': False,
#    'V_strong': False,
#    'V_pieces': False,
#    'V_success': False,
#    'V_men': False,
#    'V_else': False,
#    'V_fantasy': False,
#    'V_career': False,
#    'V_hours': False,
#    'V_though': False,
#    'V_sad': False,
#    'V_everything': False,
#    'V_got': False,
#    'V_otherwise': False,
#    'V_dull': False,
#    'V_painful': False,
#    'V_home': False,
#    'V_2002': False,
#    'V_help': False,
#    'V_thanks': False,
#    'V_whose': False,
#    'V_talent': False,
#    'V_easy': False,
#    'V_michael': False,
#    'V_ending': False,
#    'V_instead': False,
#    'V_?': False,
#    'V_sentimental': False,
#    'V_personal': False,
#    'V_wife': False,
#    'V_turn': False,
#    'V_nature': False,
#    'V_excellent': False,
#    'V_tired': False,
#    'V_enjoy': False,
#    'V_mindless': False,
#    'V_ends': False,
#    'V_viewers': False,
#    'V_interest': False,
#    'V_intelligence': False,
#    'V_actually': False,
#    'V_either': False,
#    'V_seat': False,
#    'V_parents': False,
#    'V_effects': False,
#    'V_enjoyable': False,
#    'V_green': False,
#    'V_forget': False,
#    'V_working': False,
#    'V_seems': False,
#    'V_thoughtful': False,
#    'V_debut': False,
#    'V_90': False,
#    'V_delightful': False,
#    'V_narrative': False,
#    'V_whole': False,
#    'V_act': False,
#    'V_strange': False,
#    'V_direction': False,
#    'V_since': False,
#    'V_emotions': False,
#    'V_different': False,
#    'V_tone': False,
#    'V_somewhat': False,
#    'V_hand': False,
#    'V_job': False,
#    'V_turns': False,
#    'V_surprising': False,
#    'V_rock': False,
#    'V_manages': False,
#    'V_historical': False,
#    'V_message': False,
#    'V_twists': False,
#    'V_red': False,
#    'V_teen': False,
#    'V_poor': False,
#    'V_ones': False,
#    'V_score': False,
#    'V_entirely': False,
#    'V_form': False,
#    'V_did': False,
#    'V_beautifully': False,
#    'V_intelligent': False,
#    'V_fit': False,
#    'V_none': False,
#    'V_woman': False,
#    'V_depth': False,
#    'V_along': False,
#    'V_above': False,
#    'V_sequences': False,
#    'V_live': False,
#    'V_themselves': False,
#    'V_doing': False,
#    'V_peter': False,
#    'V_looks': False,
#    'V_sure': False,
#    'V_hero': False,
#    'V_flat': False,
#    'V_visually': False,
#    'V_certainly': False,
#    'V_produced': False,
#    'V_formula': False,
#    'V_kids': False,
#    'V_twist': False,
#    'V_battle': False,
#    'V_felt': False,
#    'V_offers': False,
#    'V_comedies': False,
#    'V_unsettling': False,
#    'V_delivers': False,
#    'V_put': False,
#    'V_attempt': False,
#    'V_pace': False,
#    'V_quirky': False,
#    'V_&': False,
#    'V_tedious': False,
#    'V_mr.': False,
#    'V_effort': False,
#    'V_certain': False,
#    'V_vision': False,
#    'V_business': False,
#    'V_solid': False,
#    'V_deeply': False,
#    'V_melodrama': False,
#    'V_appealing': False,
#    'V_powerful': False,
#    'V_given': False,
#    'V_art': False,
#    'V_study': False,
#    'V_left': False,
#    'V_hold': False,
#    'V_stuff': False,
#    'V_proves': False,
#    'V_feature': False,
#    'V_pictures': False,
#    'V_gets': False,
#    'V_sharp': False,
#    'V_flaws': False,
#    'V_urban': False,
#    'V_lacks': False,
#    'V_culture': False,
#    'V_unexpected': False,
#    'V_share': False,
#    'V_grant': False,
#    'V_value': False,
#    'V_filmmaker': False,
#    'V_cultural': False,
#    'V_during': False,
#    'V_jokes': False,
#    'V_able': False,
#    'V_successful': False,
#    'V_inspiring': False,
#    'V_songs': False,
#    'V_cold': False,
#    'V_city': False,
#    'V_plenty': False,
#    'V_piece': False,
#    'V_serious': False,
#    'V_project': False,
#    'V_tragedy': False,
#    'V_modern': False,
#    'V_recent': False,
#    'V_body': False,
#    'V_vintage': False,
#    'V_rarely': False,
#    'V_clothes': False,
#    'V_care': False,
#    'V_company': False,
#    'V_treatment': False,
#    'V_huge': False,
#    'V_cut': False,
#    'V_second': False,
#    'V_belly': False,
#    'V_subtle': False,
#    'V_concept': False,
#    'V_again': False,
#    'V_part': False,
#    'V_fire': False,
#    'V_smart': False,
#    'V_writing': False,
#    'V_joke': False,
#    'V_pleasure': False,
#    'V_b-movie': False,
#    'V_lacking': False,
#    'V_problems': False,
#    'V_hope': False,
#    'V_ahead': False,
#    'V_obvious': False,
#    'V_used': False,
#    'V_coming-of-age': False,
#    'V_car': False,
#    'V_revenge': False,
#    'V_footage': False,
#    'V_possible': False,
#    'V_de': False,
#    'V_difficult': False,
#    'V_crazy': False,
#    'V_elements': False,
#    'V_already': False,
#    'V_protagonist': False,
#    'V_four': False,
#    'V_scene': False,
#    'V_members': False,
#    'V_political': False,
#    'V_tribute': False,
#    'V_excitement': False,
#    'V_role': False,
#    'V_done': False,
#    'V_romance': False,
#    'V_side': False,
#    'V_honest': False,
#    'V_let': False,
#    'V_robert': False,
#    'V_kid': False,
#    'V_oscar': False,
#    'V_!': False,
#    "V_'m": False,
#    'V_simply': False,
#    'V_dumb': False,
#    'V_spielberg': False,
#    'V_team': False,
#    'V_episode': False,
#    'V_reality': False,
#    'V_say': False,
#    'V_plays': False,
#    'V_situations': False,
#    'V_contemporary': False,
#    'V_mark': False,
#    'V_high': False,
#    'V_plain': False,
#    'V_road': False,
#    'V_glory': False,
#    'V_rare': False,
#    'V_mainstream': False,
#    'V_class': False,
#    'V_george': False,
#    'V_read': False,
#    'V_gradually': False,
#    'V_viewer': False,
#    'V_version': False,
#    'V_imagination': False,
#    'V_chris': False,
#    'V_inside': False,
#    'V_mean': False,
#    'V_despite': False,
#    'V_mind': False,
#    'V_politics': False,
#    'V_sexual': False,
#    'V_particular': False,
#    'V_sequence': False,
#    'V_performers': False,
#    'V_use': False,
#    'V_running': False,
#    'V_earnest': False,
#    'V_until': False,
#    'V_figure': False,
#    'V_tv': False,
#    'V_trouble': False,
#    'V_safe': False,
#    'V_intense': False,
#    'V_urge': False,
#    'V_including': False,
#    'V_humorous': False,
#    'V_leads': False,
#    'V_adults': False,
#    'V_ii': False,
#    'V_clever': False,
#    'V_called': False,
#    'V_novel': False,
#    'V_warm': False,
#    'V_entire': False,
#    'V_why': False,
#    'V_riveting': False,
#    'V_opera': False,
#    'V_intriguing': False,
#    'V_touching': False,
#    'V_philosophical': False,
#    'V_choices': False,
#    'V_families': False,
#    'V_white': False,
#    'V_major': False,
#    'V_indian': False,
#    'V_sympathetic': False,
#    'V_williams': False,
#    'V_loud': False,
#    'V_friendship': False,
#    'V_coming': False,
#    'V_commentary': False,
#    'V_tiresome': False,
#    'V_happens': False,
#    'V_south': False,
#    'V_pretentious': False,
#    'V_masterpiece': False,
#    'V_living': False,
#    'V_talented': False,
#    'V_captures': False,
#    'V_flawed': False,
#    'V_complex': False,
#    'V_train': False,
#    'V_perfectly': False,
#    'V_surprises': False,
#    'V_development': False,
#    'V_tom': False,
#    'V_create': False,
#    'V_easily': False,
#    'V_theme': False,
#    'V_signs': False,
#    'V_tells': False,
#    'V_emotion': False,
#    'V_tender': False,
#    'V_across': False,
#    'V_step': False,
#    'V_front': False,
#    'V_move': False,
#    'V_sheer': False,
#    'V_approach': False,
#    'V_humanity': False,
#    'V_john': False,
#    'V_run': False,
#    'V_flicks': False,
#    'V_intended': False,
#    'V_desire': False,
#    'V_barely': False,
#    'V_creepy': False,
#    'V_hit': False,
#    'V_attraction': False,
#    'V_identity': False,
#    'V_probably': False,
#    'V_bears': False,
#    'V_fails': False,
#    'V_evil': False,
#    'V_mostly': False,
#    'V_triumph': False,
#    'V_terrible': False,
#    'V_moviegoers': False,
#    'V_dance': False,
#    'V_moral': False,
#    'V_unpredictable': False,
#    'V_involved': False,
#    'V_delight': False,
#    'V_memories': False,
#    'V_happened': False,
#    'V_stay': False,
#    "V_'d": False,
#    'V_likely': False,
#    'V_highly': False,
#    'V_places': False,
#    'V_york': False,
#    'V_school': False,
#    'V_words': False,
#    'V_consistently': False,
#    'V_cliches': False,
#    'V_boys': True,
#    'V_impact': False,
#    'V_amused': False,
#    'V_soulful': False,
#    'V_disguise': False,
#    'V_waste': False,
#    'V_bullock': False,
#    'V_lovely': False,
#    'V_disbelief': False,
#    'V_credit': False,
#    'V_close': False,
#    'V_room': False,
#    'V_relationship': False,
#    'V_imax': False,
#    'V_beat': False,
#    'V_leaves': False,
#    'V_brown': False,
#    'V_level': False,
#    'V_screenplay': False,
#    'V_upon': False,
#    'V_mysterious': False,
#    'V_personality': False,
#    'V_lightweight': False,
#    'V_cross': False,
#    'V_promise': False,
#    'V_gravity': False,
#    'V_unfolds': False,
#    'V_touch': False,
#    'V_deal': False,
#    'V_impossible': False,
#    'V_fighting': False,
#    'V_relationships': False,
#    'V_brothers': False,
#    'V_subtlety': False,
#    'V_shots': False,
#    'V_taken': False,
#    'V_looking': False,
#    'V_date': False,
#    'V_expectation': False,
#    'V_store': False,
#    'V_unique': False,
#    'V_directing': False,
#    'V_setting': False,
#    'V_contrived': False,
#    'V_artificial': False,
#    'V_hair': False,
#    'V_older': False,
#    'V_interested': False,
#    'V_appeal': False,
#    'V_believe': False,
#    'V_list': False,
#    'V_throughout': False,
#    'V_sequels': False,
#    'V_sea': False,
#    'V_mechanical': False,
#    'V_magic': False,
#    'V_silent': False,
#    'V_always': False,
#    'V_overcome': False,
#    'V_vivid': False,
#    'V_brilliant': False,
#    'V_exciting': False,
#    'V_storytelling': False,
#    'V_rooting': False,
#    'V_capable': False,
#    'V_memory': False,
#    'V_james': False,
#    'V_real-life': False,
#    'V_terrific': False,
#    'V_emotionally': False,
#    'V_wrong': False,
#    'V_nice': False,
#    'V_dead': False,
#    'V_filmmakers': False,
#    'V_shows': False,
#    'V_mix': False,
#    'V_dog': False,
#    'V_sell': False,
#    'V_heavy': False,
#    'V_century': False,
#    'V_standards': False,
#    'V_thinks': False,
#    'V_view': False,
#    'V_america': False,
#    'V_cause': False,
#    'V_chase': False,
#    'V_seeks': False,
#    'V_blade': False,
#    'V_tries': False,
#    'V_getting': False,
#    'V_blue': False,
#    'V_late': False,
#    'V_ya-ya': False,
#    'V_conventional': False,
#    'V_language': False,
#    'V_middle': False,
#    'V_era': False,
#    'V_wanted': False,
#    'V_crafted': False,
#    'V_ugly': False,
#    'V_mixture': False,
#    'V_spectacle': False,
#    'V_pinocchio': False,
#    'V_television': False,
#    'V_melodramatic': False,
#    'V_nor': False,
#    'V_gags': False,
#    'V_spend': False,
#    'V_gone': False,
#    'V_further': False,
#    'V_inconsequential': False,
#    'V_bang': False,
#    'V_utterly': False,
#    'V_child': False,
#    'V_memorable': False,
#    'V_breaks': False,
#    'V_target': False,
#    'V_tragic': False,
#    'V_fresh': False,
#    'V_harmless': False,
#    'V_except': False,
#    'V_glimpse': False,
#    'V_each': False,
#    'V_rewards': False,
#    'V_college': False,
#    'V_poetry': False,
#    'V_extreme': False,
#    'V_ideas': False,
#    'V_important': False,
#    'V_disney': False,
#    'V_ultimate': False,
#    'V_actor': False,
#    'V_smile': False,
#    'V_general': False,
#    'V_writer-director': False,
#    'V_quiet': False,
#    'V_secret': False,
#    'V_country': False,
#    'V_universal': False,
#    'V_night': False,
#    'V_needed': False,
#    'V_photographed': False,
#    'V_uses': False,
#    'V_stand': False,
#    'V_gorgeous': False,
#    'V_actress': False,
#    'V_er': False,
#    'V_swallow': False,
#    'V_sitcom': False,
#    'V_preposterous': False,
#    'V_based': False,
#    'V_kung': False,
#    'V_awful': False,
#    'V_beyond': False,
#    'V_air': False,
#    'V_simple': False,
#    'V_telling': False,
#    'V_alone': False,
#    'V_editing': False,
#    'V_miracle': False,
#    'V_genuinely': False,
#    'V_wait': False,
#    'V_steven': False,
#    'V_combination': False,
#    'V_giant': False,
#    'V_potential': False,
#    'V_death': False,
#    'V_production': False,
#    'V_effective': False,
#    'V_taste': False,
#    'V_janice': False,
#    'V_convincing': False,
#    'V_wants': False,
#    'V_pay': False,
#    'V_behavior': False,
#    'V_allowed': False,
#    'V_cool': False,
#    'V_polanski': False,
#    'V_offering': False,
#    'V_pointless': False,
#    'V_eye': False,
#    'V_written': False,
#    'V_nicely': False,
#    'V_bland': False,
#    'V_open': False,
#    'V_hell': False,
#    'V_worthy': False,
#    'V_girls': False,
#    'V_industry': False,
#    'V_food': False,
#    'V_joy': False,
#    'V_society': False,
#    'V_third': False,
#    'V_slightly': False,
#    'V_roots': False,
#    'V_intent': False,
#    'V_staged': False,
#    'V_passion': False,
#    'V_clooney': False,
#    'V_biting': False,
#    'V_subjects': False,
#    'V_becomes': False,
#    'V_meditation': False,
#    'V_unnecessary': False,
#    'V_must': False,
#    'V_circumstances': False,
#    'V_herself': False,
#    'V_return': False,
#    'V_suspend': False,
#    'V_trademark': False,
#    'V_document': False,
#    'V_extraordinary': False,
#    'V_apparent': False,
#    'V_screenwriting': False,
#    'V_single': False,
#    'V_endless': False,
#    'V_attention': False,
#    'V_release': False,
#    'V_onto': False,
#    'V_cutting': False,
#    'V_screenwriters': False,
#    'V_ring': False,
#    'V_issues': False,
#    'V_frank': False,
#    'V_jerry': False,
#    'V_complete': False,
#    'V_goofy': False,
#    'V_lyrical': False,
#    'V_potent': False,
#    'V_chemistry': False,
#    'V_group': False,
#    'V_jones': False,
#    'V_starts': False,
#    'V_exhilarating': False,
#    'V_conduct': False,
#    'V_overall': False,
#    'V_mood': False,
#    'V_master': False,
#    'V_persona': False,
#    'V_son': False,
#    'V_submarine': False,
#    'V_japanese': False,
#    'V_ensemble': False,
#    'V_players': False,
#    'V_tradition': False,
#    'V_marriage': False,
#    'V_play': False,
#    'V_intentions': False,
#    'V_rest': False,
#    'V_barbershop': False,
#    'V_others': False,
#    'V_particularly': False,
#    'V_poignant': False,
#    'V_start': False,
#    'V_merely': False,
#    'V_eyes': False,
#    'V_happen': False,
#    'V_musical': False,
#    'V_god': False,
#    'V_genial': False,
#    'V_enigmatic': False,
#    'V_tons': False,
#    'V_choose': False,
#    'V_self-satisfied': False,
#    'V_equally': False,
#    'V_spirits': False,
#    'V_started': False,
#    'V_ability': False,
#    'V_straight': False,
#    'V_realism': False,
#    ...},
#   2)]

# %%
negfeaturesets[:1]
# Out:
# [({'V_the': True,
#    'V_NOTthe': False,
#    'V_,': False,
#    'V_NOT,': False,
#    'V_a': False,
#    'V_NOTa': False,
#    'V_and': False,
#    'V_NOTand': False,
#    'V_of': False,
#    'V_NOTof': False,
#    'V_to': False,
#    'V_NOTto': False,
#    'V_.': False,
#    'V_NOT.': False,
#    "V_'s": False,
#    "V_NOT's": False,
#    'V_is': False,
#    'V_NOTis': False,
#    'V_in': False,
#    'V_NOTin': False,
#    'V_that': False,
#    'V_NOTthat': False,
#    'V_it': False,
#    'V_NOTit': False,
#    'V_as': False,
#    'V_NOTas': False,
#    'V_with': False,
#    'V_NOTwith': False,
#    'V_for': False,
#    'V_NOTfor': False,
#    'V_its': False,
#    'V_NOTits': False,
#    'V_an': False,
#    'V_NOTan': False,
#    'V_film': False,
#    'V_NOTfilm': False,
#    'V_movie': False,
#    'V_NOTmovie': False,
#    'V_you': False,
#    'V_NOTyou': False,
#    'V_but': False,
#    'V_NOTbut': False,
#    'V_this': False,
#    'V_NOTthis': False,
#    'V_on': False,
#    'V_NOTon': False,
#    'V_be': False,
#    'V_NOTbe': False,
#    'V_his': False,
#    'V_NOThis': False,
#    'V_more': False,
#    'V_NOTmore': False,
#    'V_has': False,
#    'V_NOThas': False,
#    'V_--': False,
#    'V_NOT--': False,
#    'V_by': False,
#    'V_NOTby': False,
#    'V_not': False,
#    'V_NOTnot': False,
#    'V_than': False,
#    'V_NOTthan': False,
#    'V_at': False,
#    'V_NOTat': False,
#    "V_n't": False,
#    "V_NOTn't": False,
#    "V_'": True,
#    "V_NOT'": False,
#    'V_all': False,
#    'V_NOTall': False,
#    'V_like': False,
#    'V_NOTlike': False,
#    'V_one': False,
#    'V_NOTone': False,
#    'V_about': False,
#    'V_NOTabout': False,
#    'V_or': False,
#    'V_NOTor': False,
#    'V_from': False,
#    'V_NOTfrom': False,
#    'V_have': False,
#    'V_NOThave': False,
#    'V_``': False,
#    'V_NOT``': False,
#    'V_are': False,
#    'V_NOTare': False,
#    'V_-rrb-': False,
#    'V_NOT-rrb-': False,
#    'V_so': False,
#    'V_NOTso': False,
#    'V_most': False,
#    'V_NOTmost': False,
#    'V_-lrb-': False,
#    'V_NOT-lrb-': False,
#    'V_`': False,
#    'V_NOT`': False,
#    'V_story': False,
#    'V_NOTstory': False,
#    'V_out': False,
#    'V_NOTout': False,
#    'V_their': False,
#    'V_NOTtheir': False,
#    'V_comedy': False,
#    'V_NOTcomedy': False,
#    'V_much': False,
#    'V_NOTmuch': False,
#    'V_good': False,
#    'V_NOTgood': False,
#    'V_your': False,
#    'V_NOTyour': False,
#    'V_into': False,
#    'V_NOTinto': False,
#    'V_who': False,
#    'V_NOTwho': False,
#    'V_characters': False,
#    'V_NOTcharacters': False,
#    'V_up': False,
#    'V_NOTup': False,
#    'V_just': False,
#    'V_NOTjust': False,
#    'V_does': False,
#    'V_NOTdoes': False,
#    'V_time': False,
#    'V_NOTtime': False,
#    'V_funny': False,
#    'V_NOTfunny': False,
#    'V_make': False,
#    'V_NOTmake': False,
#    'V_can': False,
#    'V_NOTcan': False,
#    'V_what': False,
#    'V_NOTwhat': False,
#    'V_own': False,
#    'V_NOTown': False,
#    'V_any': False,
#    'V_NOTany': False,
#    'V_some': False,
#    'V_NOTsome': False,
#    'V_i': False,
#    'V_NOTi': False,
#    'V_will': False,
#    'V_NOTwill': False,
#    'V_if': False,
#    'V_NOTif': False,
#    'V_love': False,
#    'V_NOTlove': False,
#    'V_even': False,
#    'V_NOTeven': False,
#    'V_never': False,
#    'V_NOTnever': False,
#    'V_us': False,
#    'V_NOTus': False,
#    'V_was': False,
#    'V_NOTwas': False,
#    'V_too': False,
#    'V_NOTtoo': False,
#    'V_way': False,
#    'V_NOTway': False,
#    'V_work': False,
#    'V_NOTwork': False,
#    'V_which': False,
#    'V_NOTwhich': False,
#    'V_been': False,
#    'V_NOTbeen': False,
#    'V_no': False,
#    'V_NOTno': False,
#    'V_only': False,
#    'V_NOTonly': False,
#    'V_very': False,
#    'V_NOTvery': False,
#    'V_...': False,
#    'V_NOT...': False,
#    'V_little': False,
#    'V_NOTlittle': False,
#    'V_her': False,
#    'V_NOTher': False,
#    'V_he': False,
#    'V_NOThe': False,
#    'V_audience': False,
#    'V_NOTaudience': False,
#    'V_enough': False,
#    'V_NOTenough': False,
#    'V_movies': False,
#    'V_NOTmovies': False,
#    'V_director': False,
#    'V_NOTdirector': False,
#    'V_people': False,
#    'V_NOTpeople': False,
#    'V_films': False,
#    'V_NOTfilms': False,
#    'V_plot': False,
#    'V_NOTplot': False,
#    'V_could': False,
#    'V_NOTcould': False,
#    'V_life': False,
#    'V_NOTlife': False,
#    'V_new': False,
#    'V_NOTnew': False,
#    'V_something': False,
#    'V_NOTsomething': False,
#    'V_off': False,
#    'V_NOToff': False,
#    'V_action': False,
#    'V_NOTaction': False,
#    'V_they': False,
#    'V_NOTthey': False,
#    'V_through': False,
#    'V_NOTthrough': False,
#    'V_we': False,
#    'V_NOTwe': False,
#    'V_while': False,
#    'V_NOTwhile': False,
#    'V_many': False,
#    'V_NOTmany': False,
#    'V_these': False,
#    'V_NOTthese': False,
#    'V_real': False,
#    'V_NOTreal': False,
#    'V_see': False,
#    'V_NOTsee': False,
#    'V_those': False,
#    'V_NOTthose': False,
#    'V_there': False,
#    'V_NOTthere': False,
#    'V_bad': False,
#    'V_NOTbad': False,
#    'V_less': False,
#    'V_NOTless': False,
#    'V_hollywood': False,
#    'V_NOThollywood': False,
#    'V_when': False,
#    'V_NOTwhen': False,
#    'V_two': False,
#    'V_NOTtwo': False,
#    'V_such': False,
#    'V_NOTsuch': False,
#    'V_without': False,
#    'V_NOTwithout': False,
#    'V_minutes': False,
#    'V_NOTminutes': False,
#    'V_drama': False,
#    'V_NOTdrama': False,
#    'V_how': False,
#    'V_NOThow': False,
#    'V_also': False,
#    'V_NOTalso': False,
#    'V_man': False,
#    'V_NOTman': False,
#    'V_long': False,
#    'V_NOTlong': False,
#    'V_should': False,
#    'V_NOTshould': False,
#    'V_better': False,
#    'V_NOTbetter': False,
#    'V_big': False,
#    'V_NOTbig': False,
#    'V_made': False,
#    'V_NOTmade': False,
#    'V_makes': False,
#    'V_NOTmakes': False,
#    'V_may': False,
#    'V_NOTmay': False,
#    "V_'ve": False,
#    "V_NOT've": False,
#    'V_well': False,
#    'V_NOTwell': False,
#    'V_seen': False,
#    'V_NOTseen': False,
#    'V_ever': False,
#    'V_NOTever': False,
#    'V_few': False,
#    'V_NOTfew': False,
#    'V_down': False,
#    'V_NOTdown': False,
#    'V_character': False,
#    'V_NOTcharacter': False,
#    'V_do': False,
#    'V_NOTdo': False,
#    'V_other': False,
#    'V_NOTother': False,
#    'V_kind': False,
#    'V_NOTkind': False,
#    'V_would': False,
#    'V_NOTwould': False,
#    'V_feel': False,
#    'V_NOTfeel': False,
#    'V_another': False,
#    'V_NOTanother': False,
#    'V_between': False,
#    'V_NOTbetween': False,
#    'V_bit': False,
#    'V_NOTbit': False,
#    'V_cast': False,
#    'V_NOTcast': False,
#    'V_humor': False,
#    'V_NOThumor': False,
#    'V_heart': False,
#    'V_NOTheart': False,
#    'V_best': False,
#    'V_NOTbest': False,
#    'V_them': False,
#    'V_NOTthem': False,
#    'V_young': False,
#    'V_NOTyoung': False,
#    'V_every': False,
#    'V_NOTevery': False,
#    'V_really': False,
#    'V_NOTreally': False,
#    'V_being': False,
#    'V_NOTbeing': False,
#    'V_right': False,
#    'V_NOTright': False,
#    'V_interesting': False,
#    'V_NOTinteresting': False,
#    'V_look': False,
#    'V_NOTlook': False,
#    "V_'re": False,
#    "V_NOT're": False,
#    'V_american': False,
#    'V_NOTamerican': False,
#    'V_sense': False,
#    'V_NOTsense': False,
#    'V_war': False,
#    'V_NOTwar': False,
#    'V_great': False,
#    'V_NOTgreat': False,
#    'V_after': False,
#    'V_NOTafter': False,
#    'V_get': False,
#    'V_NOTget': False,
#    'V_world': False,
#    'V_NOTworld': False,
#    'V_watching': False,
#    'V_NOTwatching': False,
#    'V_emotional': False,
#    'V_NOTemotional': False,
#    'V_away': False,
#    'V_NOTaway': False,
#    'V_:': False,
#    'V_NOT:': False,
#    'V_take': False,
#    'V_NOTtake': False,
#    'V_almost': False,
#    'V_NOTalmost': False,
#    'V_family': False,
#    'V_NOTfamily': False,
#    'V_fun': False,
#    'V_NOTfun': False,
#    'V_me': False,
#    'V_NOTme': False,
#    'V_quite': False,
#    'V_NOTquite': False,
#    'V_both': False,
#    'V_NOTboth': False,
#    'V_nothing': False,
#    'V_NOTnothing': False,
#    'V_human': False,
#    'V_NOThuman': False,
#    'V_screen': False,
#    'V_NOTscreen': False,
#    'V_far': False,
#    'V_NOTfar': False,
#    'V_entertaining': False,
#    'V_NOTentertaining': False,
#    'V_tale': False,
#    'V_NOTtale': False,
#    'V_feels': False,
#    'V_NOTfeels': False,
#    'V_had': False,
#    'V_NOThad': False,
#    'V_original': False,
#    'V_NOToriginal': False,
#    'V_want': False,
#    'V_NOTwant': False,
#    'V_acting': False,
#    'V_NOTacting': False,
#    'V_our': False,
#    'V_NOTour': False,
#    'V_often': False,
#    'V_NOToften': False,
#    'V_thriller': False,
#    'V_NOTthriller': False,
#    'V_performances': False,
#    'V_NOTperformances': False,
#    'V_dialogue': False,
#    'V_NOTdialogue': False,
#    'V_give': False,
#    'V_NOTgive': False,
#    'V_around': False,
#    'V_NOTaround': False,
#    'V_might': False,
#    'V_NOTmight': False,
#    'V_over': False,
#    'V_NOTover': False,
#    'V_dramatic': False,
#    'V_NOTdramatic': False,
#    'V_same': False,
#    'V_NOTsame': False,
#    'V_my': False,
#    'V_NOTmy': False,
#    'V_comic': False,
#    'V_NOTcomic': False,
#    'V_subject': False,
#    'V_NOTsubject': False,
#    'V_watch': False,
#    'V_NOTwatch': False,
#    'V_were': False,
#    'V_NOTwere': False,
#    'V_material': False,
#    'V_NOTmaterial': False,
#    'V_itself': False,
#    'V_NOTitself': False,
#    'V_entertainment': False,
#    'V_NOTentertainment': False,
#    'V_worst': False,
#    'V_NOTworst': False,
#    'V_think': False,
#    'V_NOTthink': False,
#    'V_performance': False,
#    'V_NOTperformance': False,
#    'V_together': False,
#    'V_NOTtogether': False,
#    'V_hard': False,
#    'V_NOThard': False,
#    'V_making': False,
#    'V_NOTmaking': False,
#    'V_rather': False,
#    'V_NOTrather': False,
#    'V_matter': False,
#    'V_NOTmatter': False,
#    'V_year': False,
#    'V_NOTyear': False,
#    'V_first': False,
#    'V_NOTfirst': False,
#    'V_moments': False,
#    'V_NOTmoments': False,
#    'V_anything': False,
#    'V_NOTanything': False,
#    'V_where': False,
#    'V_NOTwhere': False,
#    'V_familiar': False,
#    'V_NOTfamiliar': False,
#    'V_need': False,
#    'V_NOTneed': False,
#    'V_women': False,
#    'V_NOTwomen': False,
#    'V_surprisingly': False,
#    'V_NOTsurprisingly': False,
#    'V_come': False,
#    'V_NOTcome': False,
#    'V_find': False,
#    'V_NOTfind': False,
#    'V_laughs': False,
#    'V_NOTlaughs': False,
#    'V_once': False,
#    'V_NOTonce': False,
#    'V_things': False,
#    'V_NOTthings': False,
#    'V_point': False,
#    'V_NOTpoint': False,
#    'V_compelling': False,
#    'V_NOTcompelling': False,
#    'V_;': False,
#    'V_NOT;': False,
#    'V_fans': False,
#    'V_NOTfans': False,
#    'V_next': False,
#    'V_NOTnext': False,
#    'V_\\': False,
#    'V_NOT\\': False,
#    'V_*': False,
#    'V_NOT*': False,
#    'V_show': False,
#    'V_NOTshow': False,
#    'V_script': False,
#    'V_NOTscript': False,
#    'V_pretty': False,
#    'V_NOTpretty': False,
#    'V_last': False,
#    'V_NOTlast': False,
#    'V_full': False,
#    'V_NOTfull': False,
#    'V_star': False,
#    'V_NOTstar': False,
#    'V_back': False,
#    'V_NOTback': False,
#    'V_go': False,
#    'V_NOTgo': False,
#    'V_cinema': False,
#    'V_NOTcinema': False,
#    'V_ca': False,
#    'V_NOTca': False,
#    'V_pure': False,
#    'V_NOTpure': False,
#    'V_camera': False,
#    'V_NOTcamera': False,
#    'V_dark': False,
#    'V_NOTdark': False,
#    'V_music': False,
#    'V_NOTmusic': False,
#    'V_children': False,
#    'V_NOTchildren': False,
#    'V_sweet': False,
#    'V_NOTsweet': False,
#    'V_takes': False,
#    'V_NOTtakes': False,
#    'V_line': False,
#    'V_NOTline': False,
#    'V_head': False,
#    'V_NOThead': False,
#    'V_under': False,
#    'V_NOTunder': False,
#    'V_still': False,
#    'V_NOTstill': False,
#    'V_comes': False,
#    'V_NOTcomes': False,
#    'V_three': False,
#    'V_NOTthree': False,
#    'V_video': False,
#    'V_NOTvideo': False,
#    'V_actors': False,
#    'V_NOTactors': False,
#    'V_old': False,
#    'V_NOTold': False,
#    'V_here': False,
#    'V_NOThere': False,
#    'V_because': False,
#    'V_NOTbecause': False,
#    'V_she': False,
#    'V_NOTshe': False,
#    'V_end': False,
#    'V_NOTend': False,
#    'V_then': False,
#    'V_NOTthen': False,
#    'V_thing': False,
#    'V_NOTthing': False,
#    'V_times': False,
#    'V_NOTtimes': False,
#    'V_book': False,
#    'V_NOTbook': False,
#    'V_keep': False,
#    'V_NOTkeep': False,
#    'V_day': False,
#    'V_NOTday': False,
#    'V_going': False,
#    'V_NOTgoing': False,
#    'V_anyone': False,
#    'V_NOTanyone': False,
#    'V_charming': False,
#    'V_NOTcharming': False,
#    'V_premise': False,
#    'V_NOTpremise': False,
#    'V_-': False,
#    'V_NOT-': False,
#    'V_him': False,
#    'V_NOThim': False,
#    'V_lives': False,
#    'V_NOTlives': False,
#    'V_scenes': False,
#    'V_NOTscenes': False,
#    'V_summer': False,
#    'V_NOTsummer': False,
#    'V_romantic': False,
#    'V_NOTromantic': False,
#    'V_works': False,
#    'V_NOTworks': False,
#    'V_beautiful': False,
#    'V_NOTbeautiful': False,
#    'V_short': False,
#    'V_NOTshort': False,
#    'V_cinematic': False,
#    'V_NOTcinematic': False,
#    'V_ultimately': False,
#    'V_NOTultimately': False,
#    'V_history': False,
#    'V_NOThistory': False,
#    'V_picture': False,
#    'V_NOTpicture': False,
#    'V_sometimes': False,
#    'V_NOTsometimes': False,
#    'V_genre': False,
#    'V_NOTgenre': False,
#    'V_years': False,
#    'V_NOTyears': False,
#    'V_flick': False,
#    'V_NOTflick': False,
#    'V_himself': False,
#    'V_NOThimself': False,
#    'V_before': False,
#    'V_NOTbefore': False,
#    'V_style': False,
#    'V_NOTstyle': False,
#    'V_charm': False,
#    'V_NOTcharm': False,
#    'V_visual': False,
#    'V_NOTvisual': False,
#    'V_gentle': False,
#    'V_NOTgentle': False,
#    'V_true': False,
#    'V_NOTtrue': False,
#    'V_special': False,
#    'V_NOTspecial': False,
#    'V_spirit': False,
#    'V_NOTspirit': False,
#    'V_against': False,
#    'V_NOTagainst': False,
#    'V_feeling': False,
#    'V_NOTfeeling': False,
#    'V_predictable': False,
#    'V_NOTpredictable': False,
#    'V_ride': False,
#    'V_NOTride': False,
#    'V_social': False,
#    'V_NOTsocial': False,
#    'V_face': False,
#    'V_NOTface': False,
#    'V_power': False,
#    'V_NOTpower': False,
#    'V_past': False,
#    'V_NOTpast': False,
#    'V_filmmaking': False,
#    'V_NOTfilmmaking': False,
#    'V_wit': False,
#    'V_NOTwit': False,
#    'V_hour': False,
#    'V_NOThour': False,
#    'V_goes': False,
#    'V_NOTgoes': False,
#    'V_amusing': False,
#    'V_NOTamusing': False,
#    'V_half': False,
#    'V_NOThalf': False,
#    'V_portrait': False,
#    'V_NOTportrait': False,
#    'V_set': False,
#    'V_NOTset': False,
#    'V_moving': False,
#    'V_NOTmoving': False,
#    'V_experience': False,
#    'V_NOTexperience': False,
#    'V_ambitious': False,
#    'V_NOTambitious': False,
#    'V_place': False,
#    'V_NOTplace': False,
#    'V_nearly': False,
#    'V_NOTnearly': False,
#    'V_trying': False,
#    'V_NOTtrying': False,
#    'V_now': False,
#    'V_NOTnow': False,
#    'V_title': False,
#    'V_NOTtitle': False,
#    'V_especially': False,
#    'V_NOTespecially': False,
#    'V_surprise': False,
#    'V_NOTsurprise': False,
#    'V_series': False,
#    'V_NOTseries': False,
#    'V_everyone': False,
#    'V_NOTeveryone': False,
#    'V_black': False,
#    'V_NOTblack': False,
#    'V_horror': False,
#    'V_NOThorror': False,
#    'V_become': False,
#    'V_NOTbecome': False,
#    'V_classic': False,
#    'V_NOTclassic': False,
#    'V_adventure': False,
#    'V_NOTadventure': False,
#    'V_least': False,
#    'V_NOTleast': False,
#    'V_documentary': False,
#    'V_NOTdocumentary': False,
#    'V_french': False,
#    'V_NOTfrench': False,
#    'V_lot': False,
#    'V_NOTlot': False,
#    'V_gives': False,
#    'V_NOTgives': False,
#    'V_days': False,
#    'V_NOTdays': False,
#    'V_idea': False,
#    'V_NOTidea': False,
#    'V_satisfying': False,
#    'V_NOTsatisfying': False,
#    'V_yet': False,
#    'V_NOTyet': False,
#    'V_seem': False,
#    'V_NOTseem': False,
#    'V_engaging': False,
#    'V_NOTengaging': False,
#    'V_images': False,
#    'V_NOTimages': False,
#    'V_boy': False,
#    'V_NOTboy': False,
#    'V_perfect': False,
#    'V_NOTperfect': False,
#    'V_exercise': False,
#    'V_NOTexercise': False,
#    'V_worth': False,
#    'V_NOTworth': False,
#    'V_directed': False,
#    'V_NOTdirected': False,
#    'V_fascinating': False,
#    'V_NOTfascinating': False,
#    'V_energy': False,
#    'V_NOTenergy': False,
#    'V_small': False,
#    'V_NOTsmall': False,
#    'V_warmth': False,
#    'V_NOTwarmth': False,
#    'V_ways': False,
#    'V_NOTways': False,
#    'V_change': False,
#    'V_NOTchange': False,
#    'V_shot': False,
#    'V_NOTshot': False,
#    'V_animation': False,
#    'V_NOTanimation': False,
#    'V_creative': False,
#    'V_NOTcreative': False,
#    'V_usual': False,
#    'V_NOTusual': False,
#    'V_events': False,
#    'V_NOTevents': False,
#    'V_remains': False,
#    'V_NOTremains': False,
#    'V_leave': False,
#    'V_NOTleave': False,
#    'V_theater': False,
#    'V_NOTtheater': False,
#    'V_stories': False,
#    'V_NOTstories': False,
#    'V_completely': False,
#    'V_NOTcompletely': False,
#    'V_truly': False,
#    'V_NOTtruly': False,
#    'V_know': False,
#    'V_NOTknow': False,
#    'V_tell': False,
#    'V_NOTtell': False,
#    'V_epic': False,
#    'V_NOTepic': False,
#    'V_rich': False,
#    'V_NOTrich': False,
#    'V_suspense': False,
#    'V_NOTsuspense': False,
#    'V_audiences': False,
#    'V_NOTaudiences': False,
#    'V_crime': False,
#    'V_NOTcrime': False,
#    "V_'ll": False,
#    "V_NOT'll": False,
#    'V_silly': False,
#    'V_NOTsilly': False,
#    'V_guys': False,
#    'V_NOTguys': False,
#    'V_strong': False,
#    'V_NOTstrong': False,
#    'V_pieces': False,
#    'V_NOTpieces': False,
#    'V_success': False,
#    'V_NOTsuccess': False,
#    'V_men': False,
#    'V_NOTmen': False,
#    'V_else': False,
#    'V_NOTelse': False,
#    'V_fantasy': False,
#    'V_NOTfantasy': False,
#    'V_career': False,
#    'V_NOTcareer': False,
#    'V_hours': False,
#    'V_NOThours': False,
#    'V_though': False,
#    'V_NOTthough': False,
#    'V_sad': False,
#    'V_NOTsad': False,
#    'V_everything': False,
#    'V_NOTeverything': False,
#    'V_got': False,
#    'V_NOTgot': False,
#    'V_otherwise': False,
#    'V_NOTotherwise': False,
#    'V_dull': False,
#    'V_NOTdull': False,
#    'V_painful': False,
#    'V_NOTpainful': False,
#    'V_home': False,
#    'V_NOThome': False,
#    'V_2002': False,
#    'V_NOT2002': False,
#    'V_help': False,
#    'V_NOThelp': False,
#    'V_thanks': False,
#    'V_NOTthanks': False,
#    'V_whose': False,
#    'V_NOTwhose': False,
#    'V_talent': False,
#    'V_NOTtalent': False,
#    'V_easy': False,
#    'V_NOTeasy': False,
#    'V_michael': False,
#    'V_NOTmichael': False,
#    'V_ending': False,
#    'V_NOTending': False,
#    'V_instead': False,
#    'V_NOTinstead': False,
#    'V_?': False,
#    'V_NOT?': False,
#    'V_sentimental': False,
#    'V_NOTsentimental': False,
#    'V_personal': False,
#    'V_NOTpersonal': False,
#    'V_wife': False,
#    'V_NOTwife': False,
#    'V_turn': False,
#    'V_NOTturn': False,
#    'V_nature': False,
#    'V_NOTnature': False,
#    'V_excellent': False,
#    'V_NOTexcellent': False,
#    'V_tired': False,
#    'V_NOTtired': False,
#    'V_enjoy': False,
#    'V_NOTenjoy': False,
#    'V_mindless': False,
#    'V_NOTmindless': False,
#    'V_ends': False,
#    'V_NOTends': False,
#    'V_viewers': False,
#    'V_NOTviewers': False,
#    'V_interest': False,
#    'V_NOTinterest': False,
#    'V_intelligence': False,
#    'V_NOTintelligence': False,
#    'V_actually': False,
#    'V_NOTactually': False,
#    'V_either': False,
#    'V_NOTeither': False,
#    'V_seat': False,
#    'V_NOTseat': False,
#    'V_parents': False,
#    'V_NOTparents': False,
#    'V_effects': False,
#    'V_NOTeffects': False,
#    'V_enjoyable': False,
#    'V_NOTenjoyable': False,
#    'V_green': False,
#    'V_NOTgreen': False,
#    'V_forget': False,
#    'V_NOTforget': False,
#    'V_working': False,
#    'V_NOTworking': False,
#    'V_seems': False,
#    'V_NOTseems': False,
#    'V_thoughtful': False,
#    'V_NOTthoughtful': False,
#    'V_debut': False,
#    'V_NOTdebut': False,
#    'V_90': False,
#    'V_NOT90': False,
#    'V_delightful': False,
#    'V_NOTdelightful': False,
#    'V_narrative': False,
#    'V_NOTnarrative': False,
#    'V_whole': False,
#    'V_NOTwhole': False,
#    'V_act': False,
#    'V_NOTact': False,
#    'V_strange': False,
#    'V_NOTstrange': False,
#    'V_direction': False,
#    'V_NOTdirection': False,
#    'V_since': False,
#    'V_NOTsince': False,
#    'V_emotions': False,
#    'V_NOTemotions': False,
#    'V_different': False,
#    'V_NOTdifferent': False,
#    'V_tone': False,
#    'V_NOTtone': False,
#    'V_somewhat': False,
#    'V_NOTsomewhat': False,
#    'V_hand': False,
#    'V_NOThand': False,
#    'V_job': False,
#    'V_NOTjob': False,
#    'V_turns': False,
#    'V_NOTturns': False,
#    'V_surprising': False,
#    'V_NOTsurprising': False,
#    'V_rock': False,
#    'V_NOTrock': False,
#    'V_manages': False,
#    'V_NOTmanages': False,
#    'V_historical': False,
#    'V_NOThistorical': False,
#    'V_message': False,
#    'V_NOTmessage': False,
#    'V_twists': False,
#    'V_NOTtwists': False,
#    'V_red': False,
#    'V_NOTred': False,
#    'V_teen': False,
#    'V_NOTteen': False,
#    'V_poor': False,
#    'V_NOTpoor': False,
#    'V_ones': False,
#    'V_NOTones': False,
#    'V_score': False,
#    'V_NOTscore': False,
#    'V_entirely': False,
#    'V_NOTentirely': False,
#    'V_form': False,
#    'V_NOTform': False,
#    'V_did': False,
#    'V_NOTdid': False,
#    'V_beautifully': False,
#    'V_NOTbeautifully': False,
#    'V_intelligent': False,
#    'V_NOTintelligent': False,
#    'V_fit': False,
#    'V_NOTfit': False,
#    'V_none': False,
#    'V_NOTnone': False,
#    'V_woman': False,
#    'V_NOTwoman': False,
#    'V_depth': False,
#    'V_NOTdepth': False,
#    'V_along': False,
#    'V_NOTalong': False,
#    'V_above': False,
#    'V_NOTabove': False,
#    'V_sequences': False,
#    'V_NOTsequences': False,
#    'V_live': False,
#    'V_NOTlive': False,
#    'V_themselves': False,
#    'V_NOTthemselves': False,
#    'V_doing': False,
#    'V_NOTdoing': False,
#    'V_peter': False,
#    'V_NOTpeter': False,
#    'V_looks': False,
#    'V_NOTlooks': False,
#    'V_sure': False,
#    'V_NOTsure': False,
#    'V_hero': False,
#    'V_NOThero': False,
#    'V_flat': False,
#    'V_NOTflat': False,
#    'V_visually': False,
#    'V_NOTvisually': False,
#    'V_certainly': False,
#    'V_NOTcertainly': False,
#    'V_produced': False,
#    'V_NOTproduced': False,
#    'V_formula': False,
#    'V_NOTformula': False,
#    'V_kids': False,
#    'V_NOTkids': False,
#    'V_twist': False,
#    'V_NOTtwist': False,
#    'V_battle': False,
#    'V_NOTbattle': False,
#    'V_felt': False,
#    'V_NOTfelt': False,
#    'V_offers': False,
#    'V_NOToffers': False,
#    'V_comedies': False,
#    'V_NOTcomedies': False,
#    'V_unsettling': False,
#    'V_NOTunsettling': False,
#    'V_delivers': False,
#    'V_NOTdelivers': False,
#    'V_put': False,
#    'V_NOTput': False,
#    'V_attempt': False,
#    'V_NOTattempt': False,
#    'V_pace': False,
#    'V_NOTpace': False,
#    'V_quirky': False,
#    'V_NOTquirky': False,
#    'V_&': False,
#    'V_NOT&': False,
#    'V_tedious': False,
#    'V_NOTtedious': False,
#    'V_mr.': False,
#    'V_NOTmr.': False,
#    'V_effort': False,
#    'V_NOTeffort': False,
#    'V_certain': False,
#    'V_NOTcertain': False,
#    'V_vision': False,
#    'V_NOTvision': False,
#    'V_business': False,
#    'V_NOTbusiness': False,
#    'V_solid': False,
#    'V_NOTsolid': False,
#    ...},
#   2)]

# %%
bigramfeaturesets[:1]
# Out:
# [({'V_the': True,
#    'V_,': False,
#    'V_a': False,
#    'V_and': False,
#    'V_of': False,
#    'V_to': False,
#    'V_.': False,
#    "V_'s": False,
#    'V_is': False,
#    'V_in': False,
#    'V_that': False,
#    'V_it': False,
#    'V_as': False,
#    'V_with': False,
#    'V_for': False,
#    'V_its': False,
#    'V_an': False,
#    'V_film': False,
#    'V_movie': False,
#    'V_you': False,
#    'V_but': False,
#    'V_this': False,
#    'V_on': False,
#    'V_be': False,
#    'V_his': False,
#    'V_more': False,
#    'V_has': False,
#    'V_--': False,
#    'V_by': False,
#    'V_not': False,
#    'V_than': False,
#    'V_at': False,
#    "V_n't": False,
#    "V_'": True,
#    'V_all': False,
#    'V_like': False,
#    'V_one': False,
#    'V_about': False,
#    'V_or': False,
#    'V_from': False,
#    'V_have': False,
#    'V_``': False,
#    'V_are': False,
#    'V_-rrb-': False,
#    'V_so': False,
#    'V_most': False,
#    'V_-lrb-': False,
#    'V_`': False,
#    'V_story': False,
#    'V_out': False,
#    'V_their': False,
#    'V_comedy': False,
#    'V_much': False,
#    'V_good': False,
#    'V_your': False,
#    'V_into': False,
#    'V_who': False,
#    'V_characters': False,
#    'V_up': False,
#    'V_just': False,
#    'V_does': False,
#    'V_time': False,
#    'V_funny': False,
#    'V_make': False,
#    'V_can': False,
#    'V_what': False,
#    'V_own': False,
#    'V_any': False,
#    'V_some': False,
#    'V_i': False,
#    'V_will': False,
#    'V_if': False,
#    'V_love': False,
#    'V_even': False,
#    'V_never': False,
#    'V_us': False,
#    'V_was': False,
#    'V_too': False,
#    'V_way': False,
#    'V_work': False,
#    'V_which': False,
#    'V_been': False,
#    'V_no': False,
#    'V_only': False,
#    'V_very': False,
#    'V_...': False,
#    'V_little': False,
#    'V_her': False,
#    'V_he': False,
#    'V_audience': False,
#    'V_enough': False,
#    'V_movies': False,
#    'V_director': False,
#    'V_people': False,
#    'V_films': False,
#    'V_plot': False,
#    'V_could': False,
#    'V_life': False,
#    'V_new': False,
#    'V_something': False,
#    'V_off': False,
#    'V_action': False,
#    'V_they': False,
#    'V_through': False,
#    'V_we': False,
#    'V_while': False,
#    'V_many': False,
#    'V_these': False,
#    'V_real': False,
#    'V_see': False,
#    'V_those': False,
#    'V_there': False,
#    'V_bad': False,
#    'V_less': False,
#    'V_hollywood': False,
#    'V_when': False,
#    'V_two': False,
#    'V_such': False,
#    'V_without': False,
#    'V_minutes': False,
#    'V_drama': False,
#    'V_how': False,
#    'V_also': False,
#    'V_man': False,
#    'V_long': False,
#    'V_should': False,
#    'V_better': False,
#    'V_big': False,
#    'V_made': False,
#    'V_makes': False,
#    'V_may': False,
#    "V_'ve": False,
#    'V_well': False,
#    'V_seen': False,
#    'V_ever': False,
#    'V_few': False,
#    'V_down': False,
#    'V_character': False,
#    'V_do': False,
#    'V_other': False,
#    'V_kind': False,
#    'V_would': False,
#    'V_feel': False,
#    'V_another': False,
#    'V_between': False,
#    'V_bit': False,
#    'V_cast': False,
#    'V_humor': False,
#    'V_heart': False,
#    'V_best': False,
#    'V_them': False,
#    'V_young': False,
#    'V_every': False,
#    'V_really': False,
#    'V_being': False,
#    'V_right': False,
#    'V_interesting': False,
#    'V_look': False,
#    "V_'re": False,
#    'V_american': False,
#    'V_sense': False,
#    'V_war': False,
#    'V_great': False,
#    'V_after': False,
#    'V_get': False,
#    'V_world': False,
#    'V_watching': False,
#    'V_emotional': False,
#    'V_away': False,
#    'V_:': False,
#    'V_take': False,
#    'V_almost': False,
#    'V_family': False,
#    'V_fun': False,
#    'V_me': False,
#    'V_quite': False,
#    'V_both': False,
#    'V_nothing': False,
#    'V_human': False,
#    'V_screen': False,
#    'V_far': False,
#    'V_entertaining': False,
#    'V_tale': False,
#    'V_feels': False,
#    'V_had': False,
#    'V_original': False,
#    'V_want': False,
#    'V_acting': False,
#    'V_our': False,
#    'V_often': False,
#    'V_thriller': False,
#    'V_performances': False,
#    'V_dialogue': False,
#    'V_give': False,
#    'V_around': False,
#    'V_might': False,
#    'V_over': False,
#    'V_dramatic': False,
#    'V_same': False,
#    'V_my': False,
#    'V_comic': False,
#    'V_subject': False,
#    'V_watch': False,
#    'V_were': False,
#    'V_material': False,
#    'V_itself': False,
#    'V_entertainment': False,
#    'V_worst': False,
#    'V_think': False,
#    'V_performance': False,
#    'V_together': False,
#    'V_hard': False,
#    'V_making': False,
#    'V_rather': False,
#    'V_matter': False,
#    'V_year': False,
#    'V_first': False,
#    'V_moments': False,
#    'V_anything': False,
#    'V_where': False,
#    'V_familiar': False,
#    'V_need': False,
#    'V_women': False,
#    'V_surprisingly': False,
#    'V_come': False,
#    'V_find': False,
#    'V_laughs': False,
#    'V_once': False,
#    'V_things': False,
#    'V_point': False,
#    'V_compelling': False,
#    'V_;': False,
#    'V_fans': False,
#    'V_next': False,
#    'V_\\': False,
#    'V_*': False,
#    'V_show': False,
#    'V_script': False,
#    'V_pretty': False,
#    'V_last': False,
#    'V_full': False,
#    'V_star': False,
#    'V_back': False,
#    'V_go': False,
#    'V_cinema': False,
#    'V_ca': False,
#    'V_pure': False,
#    'V_camera': False,
#    'V_dark': False,
#    'V_music': False,
#    'V_children': False,
#    'V_sweet': False,
#    'V_takes': False,
#    'V_line': False,
#    'V_head': False,
#    'V_under': False,
#    'V_still': False,
#    'V_comes': False,
#    'V_three': False,
#    'V_video': False,
#    'V_actors': False,
#    'V_old': False,
#    'V_here': False,
#    'V_because': False,
#    'V_she': False,
#    'V_end': False,
#    'V_then': False,
#    'V_thing': False,
#    'V_times': False,
#    'V_book': False,
#    'V_keep': False,
#    'V_day': False,
#    'V_going': False,
#    'V_anyone': False,
#    'V_charming': False,
#    'V_premise': False,
#    'V_-': False,
#    'V_him': False,
#    'V_lives': False,
#    'V_scenes': False,
#    'V_summer': False,
#    'V_romantic': False,
#    'V_works': False,
#    'V_beautiful': False,
#    'V_short': False,
#    'V_cinematic': False,
#    'V_ultimately': False,
#    'V_history': False,
#    'V_picture': False,
#    'V_sometimes': False,
#    'V_genre': False,
#    'V_years': False,
#    'V_flick': False,
#    'V_himself': False,
#    'V_before': False,
#    'V_style': False,
#    'V_charm': False,
#    'V_visual': False,
#    'V_gentle': False,
#    'V_true': False,
#    'V_special': False,
#    'V_spirit': False,
#    'V_against': False,
#    'V_feeling': False,
#    'V_predictable': False,
#    'V_ride': False,
#    'V_social': False,
#    'V_face': False,
#    'V_power': False,
#    'V_past': False,
#    'V_filmmaking': False,
#    'V_wit': False,
#    'V_hour': False,
#    'V_goes': False,
#    'V_amusing': False,
#    'V_half': False,
#    'V_portrait': False,
#    'V_set': False,
#    'V_moving': False,
#    'V_experience': False,
#    'V_ambitious': False,
#    'V_place': False,
#    'V_nearly': False,
#    'V_trying': False,
#    'V_now': False,
#    'V_title': False,
#    'V_especially': False,
#    'V_surprise': False,
#    'V_series': False,
#    'V_everyone': False,
#    'V_black': False,
#    'V_horror': False,
#    'V_become': False,
#    'V_classic': False,
#    'V_adventure': False,
#    'V_least': False,
#    'V_documentary': False,
#    'V_french': False,
#    'V_lot': False,
#    'V_gives': False,
#    'V_days': False,
#    'V_idea': False,
#    'V_satisfying': False,
#    'V_yet': False,
#    'V_seem': False,
#    'V_engaging': False,
#    'V_images': False,
#    'V_boy': False,
#    'V_perfect': False,
#    'V_exercise': False,
#    'V_worth': False,
#    'V_directed': False,
#    'V_fascinating': False,
#    'V_energy': False,
#    'V_small': False,
#    'V_warmth': False,
#    'V_ways': False,
#    'V_change': False,
#    'V_shot': False,
#    'V_animation': False,
#    'V_creative': False,
#    'V_usual': False,
#    'V_events': False,
#    'V_remains': False,
#    'V_leave': False,
#    'V_theater': False,
#    'V_stories': False,
#    'V_completely': False,
#    'V_truly': False,
#    'V_know': False,
#    'V_tell': False,
#    'V_epic': False,
#    'V_rich': False,
#    'V_suspense': False,
#    'V_audiences': False,
#    'V_crime': False,
#    "V_'ll": False,
#    'V_silly': False,
#    'V_guys': False,
#    'V_strong': False,
#    'V_pieces': False,
#    'V_success': False,
#    'V_men': False,
#    'V_else': False,
#    'V_fantasy': False,
#    'V_career': False,
#    'V_hours': False,
#    'V_though': False,
#    'V_sad': False,
#    'V_everything': False,
#    'V_got': False,
#    'V_otherwise': False,
#    'V_dull': False,
#    'V_painful': False,
#    'V_home': False,
#    'V_2002': False,
#    'V_help': False,
#    'V_thanks': False,
#    'V_whose': False,
#    'V_talent': False,
#    'V_easy': False,
#    'V_michael': False,
#    'V_ending': False,
#    'V_instead': False,
#    'V_?': False,
#    'V_sentimental': False,
#    'V_personal': False,
#    'V_wife': False,
#    'V_turn': False,
#    'V_nature': False,
#    'V_excellent': False,
#    'V_tired': False,
#    'V_enjoy': False,
#    'V_mindless': False,
#    'V_ends': False,
#    'V_viewers': False,
#    'V_interest': False,
#    'V_intelligence': False,
#    'V_actually': False,
#    'V_either': False,
#    'V_seat': False,
#    'V_parents': False,
#    'V_effects': False,
#    'V_enjoyable': False,
#    'V_green': False,
#    'V_forget': False,
#    'V_working': False,
#    'V_seems': False,
#    'V_thoughtful': False,
#    'V_debut': False,
#    'V_90': False,
#    'V_delightful': False,
#    'V_narrative': False,
#    'V_whole': False,
#    'V_act': False,
#    'V_strange': False,
#    'V_direction': False,
#    'V_since': False,
#    'V_emotions': False,
#    'V_different': False,
#    'V_tone': False,
#    'V_somewhat': False,
#    'V_hand': False,
#    'V_job': False,
#    'V_turns': False,
#    'V_surprising': False,
#    'V_rock': False,
#    'V_manages': False,
#    'V_historical': False,
#    'V_message': False,
#    'V_twists': False,
#    'V_red': False,
#    'V_teen': False,
#    'V_poor': False,
#    'V_ones': False,
#    'V_score': False,
#    'V_entirely': False,
#    'V_form': False,
#    'V_did': False,
#    'V_beautifully': False,
#    'V_intelligent': False,
#    'V_fit': False,
#    'V_none': False,
#    'V_woman': False,
#    'V_depth': False,
#    'V_along': False,
#    'V_above': False,
#    'V_sequences': False,
#    'V_live': False,
#    'V_themselves': False,
#    'V_doing': False,
#    'V_peter': False,
#    'V_looks': False,
#    'V_sure': False,
#    'V_hero': False,
#    'V_flat': False,
#    'V_visually': False,
#    'V_certainly': False,
#    'V_produced': False,
#    'V_formula': False,
#    'V_kids': False,
#    'V_twist': False,
#    'V_battle': False,
#    'V_felt': False,
#    'V_offers': False,
#    'V_comedies': False,
#    'V_unsettling': False,
#    'V_delivers': False,
#    'V_put': False,
#    'V_attempt': False,
#    'V_pace': False,
#    'V_quirky': False,
#    'V_&': False,
#    'V_tedious': False,
#    'V_mr.': False,
#    'V_effort': False,
#    'V_certain': False,
#    'V_vision': False,
#    'V_business': False,
#    'V_solid': False,
#    'V_deeply': False,
#    'V_melodrama': False,
#    'V_appealing': False,
#    'V_powerful': False,
#    'V_given': False,
#    'V_art': False,
#    'V_study': False,
#    'V_left': False,
#    'V_hold': False,
#    'V_stuff': False,
#    'V_proves': False,
#    'V_feature': False,
#    'V_pictures': False,
#    'V_gets': False,
#    'V_sharp': False,
#    'V_flaws': False,
#    'V_urban': False,
#    'V_lacks': False,
#    'V_culture': False,
#    'V_unexpected': False,
#    'V_share': False,
#    'V_grant': False,
#    'V_value': False,
#    'V_filmmaker': False,
#    'V_cultural': False,
#    'V_during': False,
#    'V_jokes': False,
#    'V_able': False,
#    'V_successful': False,
#    'V_inspiring': False,
#    'V_songs': False,
#    'V_cold': False,
#    'V_city': False,
#    'V_plenty': False,
#    'V_piece': False,
#    'V_serious': False,
#    'V_project': False,
#    'V_tragedy': False,
#    'V_modern': False,
#    'V_recent': False,
#    'V_body': False,
#    'V_vintage': False,
#    'V_rarely': False,
#    'V_clothes': False,
#    'V_care': False,
#    'V_company': False,
#    'V_treatment': False,
#    'V_huge': False,
#    'V_cut': False,
#    'V_second': False,
#    'V_belly': False,
#    'V_subtle': False,
#    'V_concept': False,
#    'V_again': False,
#    'V_part': False,
#    'V_fire': False,
#    'V_smart': False,
#    'V_writing': False,
#    'V_joke': False,
#    'V_pleasure': False,
#    'V_b-movie': False,
#    'V_lacking': False,
#    'V_problems': False,
#    'V_hope': False,
#    'V_ahead': False,
#    'V_obvious': False,
#    'V_used': False,
#    'V_coming-of-age': False,
#    'V_car': False,
#    'V_revenge': False,
#    'V_footage': False,
#    'V_possible': False,
#    'V_de': False,
#    'V_difficult': False,
#    'V_crazy': False,
#    'V_elements': False,
#    'V_already': False,
#    'V_protagonist': False,
#    'V_four': False,
#    'V_scene': False,
#    'V_members': False,
#    'V_political': False,
#    'V_tribute': False,
#    'V_excitement': False,
#    'V_role': False,
#    'V_done': False,
#    'V_romance': False,
#    'V_side': False,
#    'V_honest': False,
#    'V_let': False,
#    'V_robert': False,
#    'V_kid': False,
#    'V_oscar': False,
#    'V_!': False,
#    "V_'m": False,
#    'V_simply': False,
#    'V_dumb': False,
#    'V_spielberg': False,
#    'V_team': False,
#    'V_episode': False,
#    'V_reality': False,
#    'V_say': False,
#    'V_plays': False,
#    'V_situations': False,
#    'V_contemporary': False,
#    'V_mark': False,
#    'V_high': False,
#    'V_plain': False,
#    'V_road': False,
#    'V_glory': False,
#    'V_rare': False,
#    'V_mainstream': False,
#    'V_class': False,
#    'V_george': False,
#    'V_read': False,
#    'V_gradually': False,
#    'V_viewer': False,
#    'V_version': False,
#    'V_imagination': False,
#    'V_chris': False,
#    'V_inside': False,
#    'V_mean': False,
#    'V_despite': False,
#    'V_mind': False,
#    'V_politics': False,
#    'V_sexual': False,
#    'V_particular': False,
#    'V_sequence': False,
#    'V_performers': False,
#    'V_use': False,
#    'V_running': False,
#    'V_earnest': False,
#    'V_until': False,
#    'V_figure': False,
#    'V_tv': False,
#    'V_trouble': False,
#    'V_safe': False,
#    'V_intense': False,
#    'V_urge': False,
#    'V_including': False,
#    'V_humorous': False,
#    'V_leads': False,
#    'V_adults': False,
#    'V_ii': False,
#    'V_clever': False,
#    'V_called': False,
#    'V_novel': False,
#    'V_warm': False,
#    'V_entire': False,
#    'V_why': False,
#    'V_riveting': False,
#    'V_opera': False,
#    'V_intriguing': False,
#    'V_touching': False,
#    'V_philosophical': False,
#    'V_choices': False,
#    'V_families': False,
#    'V_white': False,
#    'V_major': False,
#    'V_indian': False,
#    'V_sympathetic': False,
#    'V_williams': False,
#    'V_loud': False,
#    'V_friendship': False,
#    'V_coming': False,
#    'V_commentary': False,
#    'V_tiresome': False,
#    'V_happens': False,
#    'V_south': False,
#    'V_pretentious': False,
#    'V_masterpiece': False,
#    'V_living': False,
#    'V_talented': False,
#    'V_captures': False,
#    'V_flawed': False,
#    'V_complex': False,
#    'V_train': False,
#    'V_perfectly': False,
#    'V_surprises': False,
#    'V_development': False,
#    'V_tom': False,
#    'V_create': False,
#    'V_easily': False,
#    'V_theme': False,
#    'V_signs': False,
#    'V_tells': False,
#    'V_emotion': False,
#    'V_tender': False,
#    'V_across': False,
#    'V_step': False,
#    'V_front': False,
#    'V_move': False,
#    'V_sheer': False,
#    'V_approach': False,
#    'V_humanity': False,
#    'V_john': False,
#    'V_run': False,
#    'V_flicks': False,
#    'V_intended': False,
#    'V_desire': False,
#    'V_barely': False,
#    'V_creepy': False,
#    'V_hit': False,
#    'V_attraction': False,
#    'V_identity': False,
#    'V_probably': False,
#    'V_bears': False,
#    'V_fails': False,
#    'V_evil': False,
#    'V_mostly': False,
#    'V_triumph': False,
#    'V_terrible': False,
#    'V_moviegoers': False,
#    'V_dance': False,
#    'V_moral': False,
#    'V_unpredictable': False,
#    'V_involved': False,
#    'V_delight': False,
#    'V_memories': False,
#    'V_happened': False,
#    'V_stay': False,
#    "V_'d": False,
#    'V_likely': False,
#    'V_highly': False,
#    'V_places': False,
#    'V_york': False,
#    'V_school': False,
#    'V_words': False,
#    'V_consistently': False,
#    'V_cliches': False,
#    'V_boys': True,
#    'V_impact': False,
#    'V_amused': False,
#    'V_soulful': False,
#    'V_disguise': False,
#    'V_waste': False,
#    'V_bullock': False,
#    'V_lovely': False,
#    'V_disbelief': False,
#    'V_credit': False,
#    'V_close': False,
#    'V_room': False,
#    'V_relationship': False,
#    'V_imax': False,
#    'V_beat': False,
#    'V_leaves': False,
#    'V_brown': False,
#    'V_level': False,
#    'V_screenplay': False,
#    'V_upon': False,
#    'V_mysterious': False,
#    'V_personality': False,
#    'V_lightweight': False,
#    'V_cross': False,
#    'V_promise': False,
#    'V_gravity': False,
#    'V_unfolds': False,
#    'V_touch': False,
#    'V_deal': False,
#    'V_impossible': False,
#    'V_fighting': False,
#    'V_relationships': False,
#    'V_brothers': False,
#    'V_subtlety': False,
#    'V_shots': False,
#    'V_taken': False,
#    'V_looking': False,
#    'V_date': False,
#    'V_expectation': False,
#    'V_store': False,
#    'V_unique': False,
#    'V_directing': False,
#    'V_setting': False,
#    'V_contrived': False,
#    'V_artificial': False,
#    'V_hair': False,
#    'V_older': False,
#    'V_interested': False,
#    'V_appeal': False,
#    'V_believe': False,
#    'V_list': False,
#    'V_throughout': False,
#    'V_sequels': False,
#    'V_sea': False,
#    'V_mechanical': False,
#    'V_magic': False,
#    'V_silent': False,
#    'V_always': False,
#    'V_overcome': False,
#    'V_vivid': False,
#    'V_brilliant': False,
#    'V_exciting': False,
#    'V_storytelling': False,
#    'V_rooting': False,
#    'V_capable': False,
#    'V_memory': False,
#    'V_james': False,
#    'V_real-life': False,
#    'V_terrific': False,
#    'V_emotionally': False,
#    'V_wrong': False,
#    'V_nice': False,
#    'V_dead': False,
#    'V_filmmakers': False,
#    'V_shows': False,
#    'V_mix': False,
#    'V_dog': False,
#    'V_sell': False,
#    'V_heavy': False,
#    'V_century': False,
#    'V_standards': False,
#    'V_thinks': False,
#    'V_view': False,
#    'V_america': False,
#    'V_cause': False,
#    'V_chase': False,
#    'V_seeks': False,
#    'V_blade': False,
#    'V_tries': False,
#    'V_getting': False,
#    'V_blue': False,
#    'V_late': False,
#    'V_ya-ya': False,
#    'V_conventional': False,
#    'V_language': False,
#    'V_middle': False,
#    'V_era': False,
#    'V_wanted': False,
#    'V_crafted': False,
#    'V_ugly': False,
#    'V_mixture': False,
#    'V_spectacle': False,
#    'V_pinocchio': False,
#    'V_television': False,
#    'V_melodramatic': False,
#    'V_nor': False,
#    'V_gags': False,
#    'V_spend': False,
#    'V_gone': False,
#    'V_further': False,
#    'V_inconsequential': False,
#    'V_bang': False,
#    'V_utterly': False,
#    'V_child': False,
#    'V_memorable': False,
#    'V_breaks': False,
#    'V_target': False,
#    'V_tragic': False,
#    'V_fresh': False,
#    'V_harmless': False,
#    'V_except': False,
#    'V_glimpse': False,
#    'V_each': False,
#    'V_rewards': False,
#    'V_college': False,
#    'V_poetry': False,
#    'V_extreme': False,
#    'V_ideas': False,
#    'V_important': False,
#    'V_disney': False,
#    'V_ultimate': False,
#    'V_actor': False,
#    'V_smile': False,
#    'V_general': False,
#    'V_writer-director': False,
#    'V_quiet': False,
#    'V_secret': False,
#    'V_country': False,
#    'V_universal': False,
#    'V_night': False,
#    'V_needed': False,
#    'V_photographed': False,
#    'V_uses': False,
#    'V_stand': False,
#    'V_gorgeous': False,
#    'V_actress': False,
#    'V_er': False,
#    'V_swallow': False,
#    'V_sitcom': False,
#    'V_preposterous': False,
#    'V_based': False,
#    'V_kung': False,
#    'V_awful': False,
#    'V_beyond': False,
#    'V_air': False,
#    'V_simple': False,
#    'V_telling': False,
#    'V_alone': False,
#    'V_editing': False,
#    'V_miracle': False,
#    'V_genuinely': False,
#    'V_wait': False,
#    'V_steven': False,
#    'V_combination': False,
#    'V_giant': False,
#    'V_potential': False,
#    'V_death': False,
#    'V_production': False,
#    'V_effective': False,
#    'V_taste': False,
#    'V_janice': False,
#    'V_convincing': False,
#    'V_wants': False,
#    'V_pay': False,
#    'V_behavior': False,
#    'V_allowed': False,
#    'V_cool': False,
#    'V_polanski': False,
#    'V_offering': False,
#    'V_pointless': False,
#    'V_eye': False,
#    'V_written': False,
#    'V_nicely': False,
#    'V_bland': False,
#    'V_open': False,
#    'V_hell': False,
#    'V_worthy': False,
#    'V_girls': False,
#    'V_industry': False,
#    'V_food': False,
#    'V_joy': False,
#    'V_society': False,
#    'V_third': False,
#    'V_slightly': False,
#    'V_roots': False,
#    'V_intent': False,
#    'V_staged': False,
#    'V_passion': False,
#    'V_clooney': False,
#    'V_biting': False,
#    'V_subjects': False,
#    'V_becomes': False,
#    'V_meditation': False,
#    'V_unnecessary': False,
#    'V_must': False,
#    'V_circumstances': False,
#    'V_herself': False,
#    'V_return': False,
#    'V_suspend': False,
#    'V_trademark': False,
#    'V_document': False,
#    'V_extraordinary': False,
#    'V_apparent': False,
#    'V_screenwriting': False,
#    'V_single': False,
#    'V_endless': False,
#    'V_attention': False,
#    'V_release': False,
#    'V_onto': False,
#    'V_cutting': False,
#    'V_screenwriters': False,
#    'V_ring': False,
#    'V_issues': False,
#    'V_frank': False,
#    'V_jerry': False,
#    'V_complete': False,
#    'V_goofy': False,
#    'V_lyrical': False,
#    'V_potent': False,
#    'V_chemistry': False,
#    'V_group': False,
#    'V_jones': False,
#    'V_starts': False,
#    'V_exhilarating': False,
#    'V_conduct': False,
#    'V_overall': False,
#    'V_mood': False,
#    'V_master': False,
#    'V_persona': False,
#    'V_son': False,
#    'V_submarine': False,
#    'V_japanese': False,
#    'V_ensemble': False,
#    'V_players': False,
#    'V_tradition': False,
#    'V_marriage': False,
#    'V_play': False,
#    'V_intentions': False,
#    'V_rest': False,
#    'V_barbershop': False,
#    'V_others': False,
#    'V_particularly': False,
#    'V_poignant': False,
#    'V_start': False,
#    'V_merely': False,
#    'V_eyes': False,
#    'V_happen': False,
#    'V_musical': False,
#    'V_god': False,
#    'V_genial': False,
#    'V_enigmatic': False,
#    'V_tons': False,
#    'V_choose': False,
#    'V_self-satisfied': False,
#    'V_equally': False,
#    'V_spirits': False,
#    'V_started': False,
#    'V_ability': False,
#    'V_straight': False,
#    'V_realism': False,
#    ...},
#   2)]

# %%
POSfeaturesets[:1]
# Out:
# [({'contains(film)': False,
#    'contains(movie)': False,
#    'contains(not)': False,
#    "contains(n't)": False,
#    'contains(like)': False,
#    'contains(one)': False,
#    'contains(story)': False,
#    'contains(comedy)': False,
#    'contains(much)': False,
#    'contains(good)': False,
#    'contains(characters)': False,
#    'contains(time)': False,
#    'contains(funny)': False,
#    'contains(make)': False,
#    'contains(love)': False,
#    'contains(even)': False,
#    'contains(never)': False,
#    'contains(us)': False,
#    'contains(way)': False,
#    'contains(work)': False,
#    'contains(no)': False,
#    'contains(little)': False,
#    'contains(audience)': False,
#    'contains(enough)': False,
#    'contains(movies)': False,
#    'contains(director)': False,
#    'contains(people)': False,
#    'contains(films)': False,
#    'contains(plot)': False,
#    'contains(could)': False,
#    'contains(life)': False,
#    'contains(new)': False,
#    'contains(something)': False,
#    'contains(action)': False,
#    'contains(many)': False,
#    'contains(real)': False,
#    'contains(see)': False,
#    'contains(bad)': False,
#    'contains(less)': False,
#    'contains(hollywood)': False,
#    'contains(two)': False,
#    'contains(without)': False,
#    'contains(minutes)': False,
#    'contains(drama)': False,
#    'contains(also)': False,
#    'contains(man)': False,
#    'contains(long)': False,
#    'contains(better)': False,
#    'contains(big)': False,
#    'contains(made)': False,
#    'contains(makes)': False,
#    'contains(may)': False,
#    "contains('ve)": False,
#    'contains(well)': False,
#    'contains(seen)': False,
#    'contains(ever)': False,
#    'contains(character)': False,
#    'contains(kind)': False,
#    'contains(would)': False,
#    'contains(feel)': False,
#    'contains(another)': False,
#    'contains(bit)': False,
#    'contains(cast)': False,
#    'contains(humor)': False,
#    'contains(heart)': False,
#    'contains(best)': False,
#    'contains(young)': False,
#    'contains(every)': False,
#    'contains(really)': False,
#    'contains(right)': False,
#    'contains(interesting)': False,
#    'contains(look)': False,
#    "contains('re)": False,
#    'contains(american)': False,
#    'contains(sense)': False,
#    'contains(war)': False,
#    'contains(great)': False,
#    'contains(get)': False,
#    'contains(world)': False,
#    'contains(watching)': False,
#    'contains(emotional)': False,
#    'contains(away)': False,
#    'contains(take)': False,
#    'contains(almost)': False,
#    'contains(family)': False,
#    'contains(fun)': False,
#    'contains(quite)': False,
#    'contains(nothing)': False,
#    'contains(human)': False,
#    'contains(screen)': False,
#    'contains(far)': False,
#    'contains(entertaining)': False,
#    'contains(tale)': False,
#    'contains(feels)': False,
#    'contains(original)': False,
#    'contains(want)': False,
#    'contains(acting)': False,
#    'contains(often)': False,
#    'contains(thriller)': False,
#    'contains(performances)': False,
#    'contains(dialogue)': False,
#    'contains(give)': False,
#    'contains(around)': False,
#    'contains(might)': False,
#    'contains(dramatic)': False,
#    'contains(comic)': False,
#    'contains(subject)': False,
#    'contains(watch)': False,
#    'contains(material)': False,
#    'contains(entertainment)': False,
#    'contains(worst)': False,
#    'contains(think)': False,
#    'contains(performance)': False,
#    'contains(together)': False,
#    'contains(hard)': False,
#    'contains(making)': False,
#    'contains(rather)': False,
#    'contains(matter)': False,
#    'contains(year)': False,
#    'contains(first)': False,
#    'contains(moments)': False,
#    'contains(anything)': False,
#    'contains(familiar)': False,
#    'contains(need)': False,
#    'contains(women)': False,
#    'contains(surprisingly)': False,
#    'contains(come)': False,
#    'contains(find)': False,
#    'contains(laughs)': False,
#    'contains(things)': False,
#    'contains(point)': False,
#    'contains(compelling)': False,
#    'contains(;)': False,
#    'contains(fans)': False,
#    'contains(next)': False,
#    'contains(\\)': False,
#    'contains(*)': False,
#    'contains(show)': False,
#    'contains(script)': False,
#    'contains(pretty)': False,
#    'contains(last)': False,
#    'contains(full)': False,
#    'contains(star)': False,
#    'contains(back)': False,
#    'contains(go)': False,
#    'contains(cinema)': False,
#    'contains(ca)': False,
#    'contains(pure)': False,
#    'contains(camera)': False,
#    'contains(dark)': False,
#    'contains(music)': False,
#    'contains(children)': False,
#    'contains(sweet)': False,
#    'contains(takes)': False,
#    'contains(line)': False,
#    'contains(head)': False,
#    'contains(still)': False,
#    'contains(comes)': False,
#    'contains(three)': False,
#    'contains(video)': False,
#    'contains(actors)': False,
#    'contains(old)': False,
#    'contains(end)': False,
#    'contains(thing)': False,
#    'contains(times)': False,
#    'contains(book)': False,
#    'contains(keep)': False,
#    'contains(day)': False,
#    'contains(going)': False,
#    'contains(anyone)': False,
#    'contains(charming)': False,
#    'contains(premise)': False,
#    'contains(-)': False,
#    'contains(lives)': False,
#    'contains(scenes)': False,
#    'contains(summer)': False,
#    'contains(romantic)': False,
#    'contains(works)': False,
#    'contains(beautiful)': False,
#    'contains(short)': False,
#    'contains(cinematic)': False,
#    'contains(ultimately)': False,
#    'contains(history)': False,
#    'contains(picture)': False,
#    'contains(sometimes)': False,
#    'contains(genre)': False,
#    'contains(years)': False,
#    'contains(flick)': False,
#    'contains(style)': False,
#    'contains(charm)': False,
#    'contains(visual)': False,
#    'contains(gentle)': False,
#    'contains(true)': False,
#    'contains(special)': False,
#    'contains(spirit)': False,
#    'contains(feeling)': False,
#    'contains(predictable)': False,
#    'contains(ride)': False,
#    'contains(social)': False,
#    'contains(face)': False,
#    'contains(power)': False,
#    'contains(past)': False,
#    'contains(filmmaking)': False,
#    'contains(wit)': False,
#    'contains(hour)': False,
#    'contains(goes)': False,
#    'contains(amusing)': False,
#    'contains(half)': False,
#    'contains(portrait)': False,
#    'contains(set)': False,
#    'contains(moving)': False,
#    'contains(experience)': False,
#    'contains(ambitious)': False,
#    'contains(place)': False,
#    'contains(nearly)': False,
#    'contains(trying)': False,
#    'contains(title)': False,
#    'contains(especially)': False,
#    'contains(surprise)': False,
#    'contains(series)': False,
#    'contains(everyone)': False,
#    'contains(black)': False,
#    'contains(horror)': False,
#    'contains(become)': False,
#    'contains(classic)': False,
#    'contains(adventure)': False,
#    'contains(least)': False,
#    'contains(documentary)': False,
#    'contains(french)': False,
#    'contains(lot)': False,
#    'contains(gives)': False,
#    'contains(days)': False,
#    'contains(idea)': False,
#    'contains(satisfying)': False,
#    'contains(yet)': False,
#    'contains(seem)': False,
#    'contains(engaging)': False,
#    'contains(images)': False,
#    'contains(boy)': False,
#    'contains(perfect)': False,
#    'contains(exercise)': False,
#    'contains(worth)': False,
#    'contains(directed)': False,
#    'contains(fascinating)': False,
#    'contains(energy)': False,
#    'contains(small)': False,
#    'contains(warmth)': False,
#    'contains(ways)': False,
#    'contains(change)': False,
#    'contains(shot)': False,
#    'contains(animation)': False,
#    'contains(creative)': False,
#    'contains(usual)': False,
#    'contains(events)': False,
#    'contains(remains)': False,
#    'contains(leave)': False,
#    'contains(theater)': False,
#    'contains(stories)': False,
#    'contains(completely)': False,
#    'contains(truly)': False,
#    'contains(know)': False,
#    'contains(tell)': False,
#    'contains(epic)': False,
#    'contains(rich)': False,
#    'contains(suspense)': False,
#    'contains(audiences)': False,
#    'contains(crime)': False,
#    "contains('ll)": False,
#    'contains(silly)': False,
#    'contains(guys)': False,
#    'contains(strong)': False,
#    'contains(pieces)': False,
#    'contains(success)': False,
#    'contains(men)': False,
#    'contains(else)': False,
#    'contains(fantasy)': False,
#    'contains(career)': False,
#    'contains(hours)': False,
#    'contains(though)': False,
#    'contains(sad)': False,
#    'contains(everything)': False,
#    'contains(got)': False,
#    'contains(otherwise)': False,
#    'contains(dull)': False,
#    'contains(painful)': False,
#    'contains(home)': False,
#    'contains(2002)': False,
#    'contains(help)': False,
#    'contains(thanks)': False,
#    'contains(whose)': False,
#    'contains(talent)': False,
#    'contains(easy)': False,
#    'contains(michael)': False,
#    'contains(ending)': False,
#    'contains(instead)': False,
#    'contains(?)': False,
#    'contains(sentimental)': False,
#    'contains(personal)': False,
#    'contains(wife)': False,
#    'contains(turn)': False,
#    'contains(nature)': False,
#    'contains(excellent)': False,
#    'contains(tired)': False,
#    'contains(enjoy)': False,
#    'contains(mindless)': False,
#    'contains(ends)': False,
#    'contains(viewers)': False,
#    'contains(interest)': False,
#    'contains(intelligence)': False,
#    'contains(actually)': False,
#    'contains(either)': False,
#    'contains(seat)': False,
#    'contains(parents)': False,
#    'contains(effects)': False,
#    'contains(enjoyable)': False,
#    'contains(green)': False,
#    'contains(forget)': False,
#    'contains(working)': False,
#    'contains(seems)': False,
#    'contains(thoughtful)': False,
#    'contains(debut)': False,
#    'contains(90)': False,
#    'contains(delightful)': False,
#    'contains(narrative)': False,
#    'contains(whole)': False,
#    'contains(act)': False,
#    'contains(strange)': False,
#    'contains(direction)': False,
#    'contains(since)': False,
#    'contains(emotions)': False,
#    'contains(different)': False,
#    'contains(tone)': False,
#    'contains(somewhat)': False,
#    'contains(hand)': False,
#    'contains(job)': False,
#    'contains(turns)': False,
#    'contains(surprising)': False,
#    'contains(rock)': False,
#    'contains(manages)': False,
#    'contains(historical)': False,
#    'contains(message)': False,
#    'contains(twists)': False,
#    'contains(red)': False,
#    'contains(teen)': False,
#    'contains(poor)': False,
#    'contains(ones)': False,
#    'contains(score)': False,
#    'contains(entirely)': False,
#    'contains(form)': False,
#    'contains(beautifully)': False,
#    'contains(intelligent)': False,
#    'contains(fit)': False,
#    'contains(none)': False,
#    'contains(woman)': False,
#    'contains(depth)': False,
#    'contains(along)': False,
#    'contains(sequences)': False,
#    'contains(live)': False,
#    'contains(peter)': False,
#    'contains(looks)': False,
#    'contains(sure)': False,
#    'contains(hero)': False,
#    'contains(flat)': False,
#    'contains(visually)': False,
#    'contains(certainly)': False,
#    'contains(produced)': False,
#    'contains(formula)': False,
#    'contains(kids)': False,
#    'contains(twist)': False,
#    'contains(battle)': False,
#    'contains(felt)': False,
#    'contains(offers)': False,
#    'contains(comedies)': False,
#    'contains(unsettling)': False,
#    'contains(delivers)': False,
#    'contains(put)': False,
#    'contains(attempt)': False,
#    'contains(pace)': False,
#    'contains(quirky)': False,
#    'contains(&)': False,
#    'contains(tedious)': False,
#    'contains(mr.)': False,
#    'contains(effort)': False,
#    'contains(certain)': False,
#    'contains(vision)': False,
#    'contains(business)': False,
#    'contains(solid)': False,
#    'contains(deeply)': False,
#    'contains(melodrama)': False,
#    'contains(appealing)': False,
#    'contains(powerful)': False,
#    'contains(given)': False,
#    'contains(art)': False,
#    'contains(study)': False,
#    'contains(left)': False,
#    'contains(hold)': False,
#    'contains(stuff)': False,
#    'contains(proves)': False,
#    'contains(feature)': False,
#    'contains(pictures)': False,
#    'contains(gets)': False,
#    'contains(sharp)': False,
#    'contains(flaws)': False,
#    'contains(urban)': False,
#    'contains(lacks)': False,
#    'contains(culture)': False,
#    'contains(unexpected)': False,
#    'contains(share)': False,
#    'contains(grant)': False,
#    'contains(value)': False,
#    'contains(filmmaker)': False,
#    'contains(cultural)': False,
#    'contains(jokes)': False,
#    'contains(able)': False,
#    'contains(successful)': False,
#    'contains(inspiring)': False,
#    'contains(songs)': False,
#    'contains(cold)': False,
#    'contains(city)': False,
#    'contains(plenty)': False,
#    'contains(piece)': False,
#    'contains(serious)': False,
#    'contains(project)': False,
#    'contains(tragedy)': False,
#    'contains(modern)': False,
#    'contains(recent)': False,
#    'contains(body)': False,
#    'contains(vintage)': False,
#    'contains(rarely)': False,
#    'contains(clothes)': False,
#    'contains(care)': False,
#    'contains(company)': False,
#    'contains(treatment)': False,
#    'contains(huge)': False,
#    'contains(cut)': False,
#    'contains(second)': False,
#    'contains(belly)': False,
#    'contains(subtle)': False,
#    'contains(concept)': False,
#    'contains(part)': False,
#    'contains(fire)': False,
#    'contains(smart)': False,
#    'contains(writing)': False,
#    'contains(joke)': False,
#    'contains(pleasure)': False,
#    'contains(b-movie)': False,
#    'contains(lacking)': False,
#    'contains(problems)': False,
#    'contains(hope)': False,
#    'contains(ahead)': False,
#    'contains(obvious)': False,
#    'contains(used)': False,
#    'contains(coming-of-age)': False,
#    'contains(car)': False,
#    'contains(revenge)': False,
#    'contains(footage)': False,
#    'contains(possible)': False,
#    'contains(de)': False,
#    'contains(difficult)': False,
#    'contains(crazy)': False,
#    'contains(elements)': False,
#    'contains(already)': False,
#    'contains(protagonist)': False,
#    'contains(four)': False,
#    'contains(scene)': False,
#    'contains(members)': False,
#    'contains(political)': False,
#    'contains(tribute)': False,
#    'contains(excitement)': False,
#    'contains(role)': False,
#    'contains(done)': False,
#    'contains(romance)': False,
#    'contains(side)': False,
#    'contains(honest)': False,
#    'contains(let)': False,
#    'contains(robert)': False,
#    'contains(kid)': False,
#    'contains(oscar)': False,
#    'contains(!)': False,
#    "contains('m)": False,
#    'contains(simply)': False,
#    'contains(dumb)': False,
#    'contains(spielberg)': False,
#    'contains(team)': False,
#    'contains(episode)': False,
#    'contains(reality)': False,
#    'contains(say)': False,
#    'contains(plays)': False,
#    'contains(situations)': False,
#    'contains(contemporary)': False,
#    'contains(mark)': False,
#    'contains(high)': False,
#    'contains(plain)': False,
#    'contains(road)': False,
#    'contains(glory)': False,
#    'contains(rare)': False,
#    'contains(mainstream)': False,
#    'contains(class)': False,
#    'contains(george)': False,
#    'contains(read)': False,
#    'contains(gradually)': False,
#    'contains(viewer)': False,
#    'contains(version)': False,
#    'contains(imagination)': False,
#    'contains(chris)': False,
#    'contains(inside)': False,
#    'contains(mean)': False,
#    'contains(despite)': False,
#    'contains(mind)': False,
#    'contains(politics)': False,
#    'contains(sexual)': False,
#    'contains(particular)': False,
#    'contains(sequence)': False,
#    'contains(performers)': False,
#    'contains(use)': False,
#    'contains(running)': False,
#    'contains(earnest)': False,
#    'contains(figure)': False,
#    'contains(tv)': False,
#    'contains(trouble)': False,
#    'contains(safe)': False,
#    'contains(intense)': False,
#    'contains(urge)': False,
#    'contains(including)': False,
#    'contains(humorous)': False,
#    'contains(leads)': False,
#    'contains(adults)': False,
#    'contains(ii)': False,
#    'contains(clever)': False,
#    'contains(called)': False,
#    'contains(novel)': False,
#    'contains(warm)': False,
#    'contains(entire)': False,
#    'contains(riveting)': False,
#    'contains(opera)': False,
#    'contains(intriguing)': False,
#    'contains(touching)': False,
#    'contains(philosophical)': False,
#    'contains(choices)': False,
#    'contains(families)': False,
#    'contains(white)': False,
#    'contains(major)': False,
#    'contains(indian)': False,
#    'contains(sympathetic)': False,
#    'contains(williams)': False,
#    'contains(loud)': False,
#    'contains(friendship)': False,
#    'contains(coming)': False,
#    'contains(commentary)': False,
#    'contains(tiresome)': False,
#    'contains(happens)': False,
#    'contains(south)': False,
#    'contains(pretentious)': False,
#    'contains(masterpiece)': False,
#    'contains(living)': False,
#    'contains(talented)': False,
#    'contains(captures)': False,
#    'contains(flawed)': False,
#    'contains(complex)': False,
#    'contains(train)': False,
#    'contains(perfectly)': False,
#    'contains(surprises)': False,
#    'contains(development)': False,
#    'contains(tom)': False,
#    'contains(create)': False,
#    'contains(easily)': False,
#    'contains(theme)': False,
#    'contains(signs)': False,
#    'contains(tells)': False,
#    'contains(emotion)': False,
#    'contains(tender)': False,
#    'contains(across)': False,
#    'contains(step)': False,
#    'contains(front)': False,
#    'contains(move)': False,
#    'contains(sheer)': False,
#    'contains(approach)': False,
#    'contains(humanity)': False,
#    'contains(john)': False,
#    'contains(run)': False,
#    'contains(flicks)': False,
#    'contains(intended)': False,
#    'contains(desire)': False,
#    'contains(barely)': False,
#    'contains(creepy)': False,
#    'contains(hit)': False,
#    'contains(attraction)': False,
#    'contains(identity)': False,
#    'contains(probably)': False,
#    'contains(bears)': False,
#    'contains(fails)': False,
#    'contains(evil)': False,
#    'contains(mostly)': False,
#    'contains(triumph)': False,
#    'contains(terrible)': False,
#    'contains(moviegoers)': False,
#    'contains(dance)': False,
#    'contains(moral)': False,
#    'contains(unpredictable)': False,
#    'contains(involved)': False,
#    'contains(delight)': False,
#    'contains(memories)': False,
#    'contains(happened)': False,
#    'contains(stay)': False,
#    "contains('d)": False,
#    'contains(likely)': False,
#    'contains(highly)': False,
#    'contains(places)': False,
#    'contains(york)': False,
#    'contains(school)': False,
#    'contains(words)': False,
#    'contains(consistently)': False,
#    'contains(cliches)': False,
#    'contains(boys)': True,
#    'contains(impact)': False,
#    'contains(amused)': False,
#    'contains(soulful)': False,
#    'contains(disguise)': False,
#    'contains(waste)': False,
#    'contains(bullock)': False,
#    'contains(lovely)': False,
#    'contains(disbelief)': False,
#    'contains(credit)': False,
#    'contains(close)': False,
#    'contains(room)': False,
#    'contains(relationship)': False,
#    'contains(imax)': False,
#    'contains(beat)': False,
#    'contains(leaves)': False,
#    'contains(brown)': False,
#    'contains(level)': False,
#    'contains(screenplay)': False,
#    'contains(upon)': False,
#    'contains(mysterious)': False,
#    'contains(personality)': False,
#    'contains(lightweight)': False,
#    'contains(cross)': False,
#    'contains(promise)': False,
#    'contains(gravity)': False,
#    'contains(unfolds)': False,
#    'contains(touch)': False,
#    'contains(deal)': False,
#    'contains(impossible)': False,
#    'contains(fighting)': False,
#    'contains(relationships)': False,
#    'contains(brothers)': False,
#    'contains(subtlety)': False,
#    'contains(shots)': False,
#    'contains(taken)': False,
#    'contains(looking)': False,
#    'contains(date)': False,
#    'contains(expectation)': False,
#    'contains(store)': False,
#    'contains(unique)': False,
#    'contains(directing)': False,
#    'contains(setting)': False,
#    'contains(contrived)': False,
#    'contains(artificial)': False,
#    'contains(hair)': False,
#    'contains(older)': False,
#    'contains(interested)': False,
#    'contains(appeal)': False,
#    'contains(believe)': False,
#    'contains(list)': False,
#    'contains(throughout)': False,
#    'contains(sequels)': False,
#    'contains(sea)': False,
#    'contains(mechanical)': False,
#    'contains(magic)': False,
#    'contains(silent)': False,
#    'contains(always)': False,
#    'contains(overcome)': False,
#    'contains(vivid)': False,
#    'contains(brilliant)': False,
#    'contains(exciting)': False,
#    'contains(storytelling)': False,
#    'contains(rooting)': False,
#    'contains(capable)': False,
#    'contains(memory)': False,
#    'contains(james)': False,
#    'contains(real-life)': False,
#    'contains(terrific)': False,
#    'contains(emotionally)': False,
#    'contains(wrong)': False,
#    'contains(nice)': False,
#    'contains(dead)': False,
#    'contains(filmmakers)': False,
#    'contains(shows)': False,
#    'contains(mix)': False,
#    'contains(dog)': False,
#    'contains(sell)': False,
#    'contains(heavy)': False,
#    'contains(century)': False,
#    'contains(standards)': False,
#    'contains(thinks)': False,
#    'contains(view)': False,
#    'contains(america)': False,
#    'contains(cause)': False,
#    'contains(chase)': False,
#    'contains(seeks)': False,
#    'contains(blade)': False,
#    'contains(tries)': False,
#    'contains(getting)': False,
#    'contains(blue)': False,
#    'contains(late)': False,
#    'contains(ya-ya)': False,
#    'contains(conventional)': False,
#    'contains(language)': False,
#    'contains(middle)': False,
#    'contains(era)': False,
#    'contains(wanted)': False,
#    'contains(crafted)': False,
#    'contains(ugly)': False,
#    'contains(mixture)': False,
#    'contains(spectacle)': False,
#    'contains(pinocchio)': False,
#    'contains(television)': False,
#    'contains(melodramatic)': False,
#    'contains(nor)': False,
#    'contains(gags)': False,
#    'contains(spend)': False,
#    'contains(gone)': False,
#    'contains(inconsequential)': False,
#    'contains(bang)': False,
#    'contains(utterly)': False,
#    'contains(child)': False,
#    'contains(memorable)': False,
#    'contains(breaks)': False,
#    'contains(target)': False,
#    'contains(tragic)': False,
#    'contains(fresh)': False,
#    'contains(harmless)': False,
#    'contains(except)': False,
#    'contains(glimpse)': False,
#    'contains(rewards)': False,
#    'contains(college)': False,
#    'contains(poetry)': False,
#    'contains(extreme)': False,
#    'contains(ideas)': False,
#    'contains(important)': False,
#    'contains(disney)': False,
#    'contains(ultimate)': False,
#    'contains(actor)': False,
#    'contains(smile)': False,
#    'contains(general)': False,
#    'contains(writer-director)': False,
#    'contains(quiet)': False,
#    'contains(secret)': False,
#    'contains(country)': False,
#    'contains(universal)': False,
#    'contains(night)': False,
#    'contains(needed)': False,
#    'contains(photographed)': False,
#    'contains(uses)': False,
#    'contains(stand)': False,
#    'contains(gorgeous)': False,
#    'contains(actress)': False,
#    'contains(er)': False,
#    'contains(swallow)': False,
#    'contains(sitcom)': False,
#    'contains(preposterous)': False,
#    'contains(based)': False,
#    'contains(kung)': False,
#    'contains(awful)': False,
#    'contains(beyond)': False,
#    'contains(air)': False,
#    'contains(simple)': False,
#    'contains(telling)': False,
#    'contains(alone)': False,
#    'contains(editing)': False,
#    'contains(miracle)': False,
#    'contains(genuinely)': False,
#    'contains(wait)': False,
#    'contains(steven)': False,
#    'contains(combination)': False,
#    'contains(giant)': False,
#    'contains(potential)': False,
#    'contains(death)': False,
#    'contains(production)': False,
#    'contains(effective)': False,
#    'contains(taste)': False,
#    'contains(janice)': False,
#    'contains(convincing)': False,
#    'contains(wants)': False,
#    'contains(pay)': False,
#    'contains(behavior)': False,
#    'contains(allowed)': False,
#    'contains(cool)': False,
#    'contains(polanski)': False,
#    'contains(offering)': False,
#    'contains(pointless)': False,
#    'contains(eye)': False,
#    'contains(written)': False,
#    'contains(nicely)': False,
#    'contains(bland)': False,
#    'contains(open)': False,
#    'contains(hell)': False,
#    'contains(worthy)': False,
#    'contains(girls)': False,
#    'contains(industry)': False,
#    'contains(food)': False,
#    'contains(joy)': False,
#    'contains(society)': False,
#    'contains(third)': False,
#    'contains(slightly)': False,
#    'contains(roots)': False,
#    'contains(intent)': False,
#    'contains(staged)': False,
#    'contains(passion)': False,
#    'contains(clooney)': False,
#    'contains(biting)': False,
#    'contains(subjects)': False,
#    'contains(becomes)': False,
#    'contains(meditation)': False,
#    'contains(unnecessary)': False,
#    'contains(must)': False,
#    'contains(circumstances)': False,
#    'contains(return)': False,
#    'contains(suspend)': False,
#    'contains(trademark)': False,
#    'contains(document)': False,
#    'contains(extraordinary)': False,
#    'contains(apparent)': False,
#    'contains(screenwriting)': False,
#    'contains(single)': False,
#    'contains(endless)': False,
#    'contains(attention)': False,
#    'contains(release)': False,
#    'contains(onto)': False,
#    'contains(cutting)': False,
#    'contains(screenwriters)': False,
#    'contains(ring)': False,
#    'contains(issues)': False,
#    'contains(frank)': False,
#    'contains(jerry)': False,
#    'contains(complete)': False,
#    'contains(goofy)': False,
#    'contains(lyrical)': False,
#    'contains(potent)': False,
#    'contains(chemistry)': False,
#    'contains(group)': False,
#    'contains(jones)': False,
#    'contains(starts)': False,
#    'contains(exhilarating)': False,
#    'contains(conduct)': False,
#    'contains(overall)': False,
#    'contains(mood)': False,
#    'contains(master)': False,
#    'contains(persona)': False,
#    'contains(son)': False,
#    'contains(submarine)': False,
#    'contains(japanese)': False,
#    'contains(ensemble)': False,
#    'contains(players)': False,
#    'contains(tradition)': False,
#    'contains(marriage)': False,
#    'contains(play)': False,
#    'contains(intentions)': False,
#    'contains(rest)': False,
#    'contains(barbershop)': False,
#    'contains(others)': False,
#    'contains(particularly)': False,
#    'contains(poignant)': False,
#    'contains(start)': False,
#    'contains(merely)': False,
#    'contains(eyes)': False,
#    'contains(happen)': False,
#    'contains(musical)': False,
#    'contains(god)': False,
#    'contains(genial)': False,
#    'contains(enigmatic)': False,
#    'contains(tons)': False,
#    'contains(choose)': False,
#    'contains(self-satisfied)': False,
#    'contains(equally)': False,
#    'contains(spirits)': False,
#    'contains(started)': False,
#    'contains(ability)': False,
#    'contains(straight)': False,
#    'contains(realism)': False,
#    'contains(twisted)': False,
#    'contains(letting)': False,
#    'contains(beauty)': False,
#    'contains(ludicrous)': False,
#    'contains(period)': False,
#    'contains(win)': False,
#    'contains(moviemaking)': False,
#    'contains(appear)': False,
#    'contains(unconvincing)': False,
#    'contains(catches)': False,
#    'contains(welcome)': False,
#    'contains(kissinger)': False,
#    'contains(drop)': False,
#    'contains(bitter)': False,
#    'contains(presentation)': False,
#    'contains(cover)': False,
#    'contains(thrills)': False,
#    'contains(exploration)': False,
#    'contains(reason)': False,
#    'contains(spy)': False,
#    'contains(2)': False,
#    'contains(subtitles)': False,
#    'contains(italian)': False,
#    'contains(theatre)': False,
#    'contains(credibility)': False,
#    'contains(subtly)': False,
#    'contains(fine)': False,
#    'contains(reno)': False,
#    'contains(fly)': False,
#    'contains(angry)': False,
#    'contains(king)': False,
#    'contains(sounds)': False,
#    'contains(holes)': False,
#    'contains(chills)': False,
#    'contains(wonderfully)': False,
#    'contains(ms.)': False,
#    'contains(dreary)': False,
#    'contains(virtually)': False,
#    'contains(rewarding)': False,
#    'contains(refugees)': False,
#    'contains(course)': False,
#    'contains(david)': False,
#    'contains(search)': False,
#    'contains(comedian)': False,
#    'contains(situation)': False,
#    'contains(drag)': False,
#    'contains(understanding)': False,
#    'contains(thinking)': False,
#    'contains(person)': False,
#    'contains(vietnam)': False,
#    'contains(climactic)': False,
#    'contains(blood)': False,
#    'contains(dry)': False,
#    'contains(age)': False,
#    'contains(damage)': False,
#    'contains(fix)': False,
#    'contains(technology)': False,
#    'contains(explosion)': False,
#    'contains(manner)': False,
#    'contains(ambiguous)': False,
#    'contains(low-budget)': False,
#    'contains(chan)': False,
#    'contains(witty)': False,
#    'contains(amount)': False,
#    'contains(saw)': False,
#    'contains(crush)': False,
#    'contains(evocative)': False,
#    'contains(sort)': False,
#    'contains(found)': False,
#    'contains(inventive)': False,
#    'contains(finally)': False,
#    'contains(early)': False,
#    'contains(portrays)': False,
#    'contains(loss)': False,
#    'contains(b)': False,
#    'contains(laughable)': False,
#    'contains(tear)': False,
#    'contains(plotting)': False,
#    'contains(borrows)': False,
#    'contains(silence)': False,
#    'contains(collision)': False,
#    'contains(spiritual)': False,
#    'contains(talk)': False,
#    'contains(gangster)': False,
#    'contains(catch)': False,
#    'contains(strength)': False,
#    'contains(poem)': False,
#    'contains(receive)': False,
#    'contains(hollow)': False,
#    'contains(striking)': False,
#    'contains(quietly)': False,
#    'contains(wasted)': False,
#    'contains(cluelessness)': False,
#    'contains(final)': False,
#    'contains(bathroom)': False,
#    'contains(wry)': False,
#    'contains(clumsy)': False,
#    'contains(main)': False,
#    'contains(example)': False,
#    'contains(opening)': False,
#    'contains(fashion)': False,
#    'contains(maybe)': False,
#    'contains(presence)': False,
#    'contains(fantasies)': False,
#    'contains(bring)': False,
#    'contains(sitting)': False,
#    'contains(pic)': False,
#    'contains(deserved)': False,
#    'contains(crowd)': False,
#    'contains(source)': False,
#    'contains(mile)': False,
#    'contains(sympathy)': False,
#    'contains(several)': False,
#    'contains(worked)': False,
#    'contains(naturalistic)': False,
#    'contains(undeniable)': False,
#    'contains(kevin)': False,
#    'contains(psychological)': False,
#    'contains(teenagers)': False,
#    'contains(tiny)': False,
#    ...},
#   2)]

# %%
#Unigram or Bag-of-Words (BOW) features; this is the baseline:
print("\nOriginal Featureset")
cross_validation_PRF(num_folds, featuresets, labels)
#Bigrams
print("\nBigrams Featureset")
cross_validation_PRF(num_folds, bigramfeaturesets, labels)
#Negation -- SHOULD BE CREATED
print("\nNegated Featureset")
cross_validation_PRF(num_folds, negfeaturesets, labels)
#POS features -- SHOULD BE CREATED
print("\nPOS Featureset")
cross_validation_PRF(num_folds, POSfeaturesets, labels)
# Out:
# Original Featureset
# Each fold size: 500
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# Fold 5
# Fold 6
# Fold 7
# Fold 8
# Fold 9
#
# Average Precision	Recall		F1 	Per Label
# 0 	      0.137      0.145      0.139
# 1 	      0.218      0.333      0.262
# 2 	      0.825      0.612      0.702
# 3 	      0.257      0.430      0.321
# 4 	      0.197      0.308      0.236
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.327      0.366      0.332
#
# Label Counts {0: 226, 1: 895, 2: 2491, 3: 1102, 4: 286}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.524      0.483      0.487
#
# Bigrams Featureset
# Each fold size: 500
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# Fold 5
# Fold 6
# Fold 7
# Fold 8
# Fold 9
#
# Average Precision	Recall		F1 	Per Label
# 0 	      0.137      0.145      0.139
# 1 	      0.218      0.333      0.262
# 2 	      0.825      0.612      0.702
# 3 	      0.257      0.430      0.321
# 4 	      0.197      0.308      0.236
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.327      0.366      0.332
#
# Label Counts {0: 226, 1: 895, 2: 2491, 3: 1102, 4: 286}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.524      0.483      0.487
#
# Negated Featureset
# Each fold size: 500
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# Fold 5
# Fold 6
# Fold 7
# Fold 8
# Fold 9
#
# Average Precision	Recall		F1 	Per Label
# 0 	      0.221      0.133      0.164
# 1 	      0.218      0.341      0.265
# 2 	      0.787      0.634      0.702
# 3 	      0.268      0.436      0.331
# 4 	      0.237      0.240      0.232
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.346      0.357      0.339
#
# Label Counts {0: 226, 1: 895, 2: 2491, 3: 1102, 4: 286}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.514      0.493      0.491
#
# POS Featureset
# Each fold size: 500
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# Fold 5
# Fold 6
# Fold 7
# Fold 8
# Fold 9
#
# Average Precision	Recall		F1 	Per Label
# 0 	      0.124      0.141      0.131
# 1 	      0.241      0.337      0.280
# 2 	      0.824      0.623      0.709
# 3 	      0.267      0.430      0.328
# 4 	      0.172      0.286      0.210
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.326      0.363      0.332
#
# Label Counts {0: 226, 1: 895, 2: 2491, 3: 1102, 4: 286}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.528      0.488      0.494
