# %% [markdown]
# ### Final Project: College Basketball Data
# Author: Jake Conard
# Class: IST652

# %% [markdown]
# ### Dataset 1 (Structured Data)

# %% [markdown]
# #### Data Source --> https://www.kaggle.com/datasets/andrewsundberg/college-basketball-dataset?resource=download

# %% [markdown]
# ###### Questions to Answer:
#
# What Stat had the highest correlation with championship caliber teams?
#
# What teams won the most Championships from 2013 - 2019?
#
# How did 2 point percentage and 3 point percentages effect Championship bids?
#
# What was the correlation between offensive and defensive stats?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data into a DataFrame and set column names
data = pd.read_csv("cbb.csv")

# %%
#show how many rows and columns are in the dataset
data.shape
# Out:
# (2455, 24)

# %%
#show what the data looks like
data.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3      Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4         Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2  ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3  ...  36.6  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019
# 4  ...  26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### Format the data a little to include postseason labels and whether or not the team qualified for March Madness

# %%
# only include teams that made the postseason tournament and drop any teams that did not.
Qaulified_For_MM = data[data['POSTSEASON'].notna()].reset_index(drop=True)
Postseason_labels = ['R68', 'R64','R32','S16','E8', 'F4','2ND','Champions']

# %%
Qaulified_For_MM.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3      Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4         Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2  ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3  ...  36.6  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019
# 4  ...  26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
#
# [5 rows x 24 columns]

# %% [markdown]
# ### What Stat had the highest correlation with chapionship caliber teams?

# %%
# create a boxplot for ADJOE: Adjusted Offensive Efficiency 
# (An estimate of the offensive efficiency (points scored per 100 possessions) a team would have against the average Division I defense)
fig = plt.figure(figsize = (10,4))
sns.boxplot(data=Qaulified_For_MM, x='POSTSEASON', y='ADJOE', order=Postseason_labels)
plt.title('Offensive Adjusted Efficiency')
# Out:
# Text(0.5, 1.0, 'Offensive Adjusted Efficiency')

# %%
#create a boxplot for ADJDE: Adjusted Defensive Efficiency (An estimate of the defensive efficiency (points allowed per 100 possessions) a team would have against the average Division I offense)
fig = plt.figure(figsize = (10,4))
sns.boxplot(data=Qaulified_For_MM, x='POSTSEASON', y='ADJDE', order=Postseason_labels)
plt.title('Adjusted Defensive Efficiency')
# Out:
# Text(0.5, 1.0, 'Adjusted Defensive Efficiency')

# %%
#create a boxplot for EFG_O: Effective Field Goal Percentage Shot
fig = plt.figure(figsize = (10,4))
sns.boxplot(data=Qaulified_For_MM, x='POSTSEASON', y='EFG_O', order=Postseason_labels)
plt.title('Effective Field Goal Percentage Shot')
# Out:
# Text(0.5, 1.0, 'Effective Field Goal Percentage Shot')

# %%
#create a boxplot for ADJ_T: Adjusted Tempo (An estimate of the tempo (possessions per 40 minutes) a team would have against the team that wants to play at an average Division I tempo)
fig = plt.figure(figsize = (10,4))
sns.boxplot(data=Qaulified_For_MM, x='POSTSEASON', y='ADJ_T', order=Postseason_labels)
plt.title('Adjusted Tempo (An estimate of the tempo (possessions per 40 minutes)')
# Out:
# Text(0.5, 1.0, 'Adjusted Tempo (An estimate of the tempo (possessions per 40 minutes)')

# %%
# create a boxplot for BARTHAG: Power Rating (Chance of beating an average Division I team)
fig = plt.figure(figsize = (10,4))
sns.boxplot(data=Qaulified_For_MM, x='POSTSEASON', y='BARTHAG', order=Postseason_labels)
plt.title('Power Rating (Chance of beating an average Division I team)')
# Out:
# Text(0.5, 1.0, 'Power Rating (Chance of beating an average Division I team)')

# %% [markdown]
# ### What teams won the most Championships from 2013 - 2019?

# %%
#df.loc[df['column_name'] == some_value]
# need to create a new dataframe that only includes the teams that won championships
df_Champ = Qaulified_For_MM.loc[Qaulified_For_MM['POSTSEASON'] == 'Champions']

# %%
df_Champ
# Out:
#               TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 7             Duke   ACC  39  35  125.2   90.6   0.9764   56.6   46.5  16.3
# 8         Virginia   ACC  38  35  123.0   89.9   0.9736   55.2   44.7  14.7
# 9   North Carolina   ACC  39  33  121.0   91.5   0.9615   51.7   48.1  16.2
# 10       Villanova    BE  40  35  123.1   90.9   0.9703   56.1   46.7  16.3
# 11       Villanova    BE  40  36  128.4   94.1   0.9725   59.5   48.5  15.0
# 12     Connecticut  Amer  40  32  112.5   91.3   0.9171   51.5   44.6  17.3
# 13      Louisville    BE  40  35  115.9   84.5   0.9743   50.6   44.8  18.3
#
#     ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 7   ...  23.9  55.9  46.3  38.7  31.4   66.4  10.7   Champions   1.0  2015
# 8   ...  26.3  52.5  45.7  39.5  28.9   60.7  11.1   Champions   1.0  2019
# 9   ...  31.6  51.0  46.3  35.5  33.9   72.8   8.4   Champions   1.0  2017
# ...

# %%
# iterate and print the names of the teams and the years they won a championship
for index, row in df_Champ.iterrows():
    print('The National Champion in D1 College Basketball for ' + str(row['YEAR']) + ' was ' + row['TEAM'])
# Out:
# The National Champion in D1 College Basketball for 2015 was Duke
# The National Champion in D1 College Basketball for 2019 was Virginia
# The National Champion in D1 College Basketball for 2017 was North Carolina
# The National Champion in D1 College Basketball for 2016 was Villanova
# The National Champion in D1 College Basketball for 2018 was Villanova
# The National Champion in D1 College Basketball for 2014 was Connecticut
# The National Champion in D1 College Basketball for 2013 was Louisville

# %% [markdown]
# ### How did 2 point percentage and 3 point percentages effect Championship bids?

# %%
#create 2 boxplots showing how 3 point percentages impact championship runs
fig, ax = plt.subplots(1,2, figsize=(20,4))
sns.boxplot(ax= ax[0], data=Qaulified_For_MM, x='POSTSEASON', y='3P_O', order=Postseason_labels)
ax[0].set_title('Offensive 3 Point Shot Percentage Made')
sns.boxplot(ax= ax[1], data=Qaulified_For_MM, x='POSTSEASON', y='3P_D', order=Postseason_labels)
ax[1].set_title('Defensive 3 Point Shot Percentage Allowed')
# Out:
# Text(0.5, 1.0, 'Defensive 3 Point Shot Percentage Allowed')

# %%
#create 2 boxplots showing how 2 point percentages impact championship runs
fig, ax = plt.subplots(1,2, figsize=(20,4))
sns.boxplot(ax= ax[0], data=Qaulified_For_MM, x='POSTSEASON', y='2P_O', order=Postseason_labels)
ax[0].set_title('Offensive 2 Point Shot Percentage Made')
sns.boxplot(ax= ax[1], data=Qaulified_For_MM, x='POSTSEASON', y='2P_D', order=Postseason_labels)
ax[1].set_title('Defensive 2 Point Shot Percentage Allowed')
# Out:
# Text(0.5, 1.0, 'Defensive 2 Point Shot Percentage Allowed')

# %% [markdown]
# ### What was the correlation between offensive and defensive stats?

# %%
# create 2 heatmaps that show how offensive and defensive stats are correlated if they are
# using seaborne to create these plots and matplot to plot them inline
Offensive_Stats = Qaulified_For_MM[['ADJOE','EFG_O','TOR','ORB','FTR','2P_O','3P_O']]
Defensive_Stats = Qaulified_For_MM[['ADJDE','EFG_D','TORD','DRB', 'FTRD', '2P_D','3P_D']]
Offensive_Corr = Offensive_Stats.corr()
Defensive_Corr = Defensive_Stats.corr()
fig, ax = plt.subplots(1,2, figsize=(20,8))
sns.heatmap(ax=ax[0], data=Offensive_Corr, cmap='magma', annot=True, center=0)
sns.heatmap(ax=ax[1], data=Defensive_Corr, cmap='magma', annot=True, center=0)
ax[0].set_title('Offensive Correlations')
ax[1].set_title('Defensive Correlations')
# Out:
# Text(0.5, 1.0, 'Defensive Correlations')

# %% [markdown]
# ### Dataset 2 (Unstructured Data | Twitter Dataset)

# %% [markdown]
# #### Import data and do some basic cleaning

# %%
import json
from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer
import regex as re
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
  
# Opening JSON file
f = open('bball_mm2.txt',)
  
# returns JSON object as
# a dictionary
data = json.load(f)

# %% [markdown]
# ### Tweet Wordcloud

# %%
# put the tweets in a list
tweets_list = [x['text'] for x in data]

# %%
# move the list to a df
df = pd.DataFrame(tweets_list,columns=['Text'])

# %%
df.head()
# Out:
#                                                 Text
# 0  RT @HowardWKYT: The final seconds of the Kentu...
# 1  RT @WhistleSports: When you perfectly time the...
# 2  RT @HowardWKYT: The final seconds of the Kentu...
# 3  RT @BleacherReport: And then there were four.....
# 4  RT @mycarolinastdnt: RT if you'll be cheering ...

# %%
df.shape
# Out:
# (2000, 1)

# %%
#Regex for cleaning
re_list = ['@[A-Za-z0–9_]+', '#']
combined_re = re.compile( '|'.join( re_list) )

regex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)

# %%
# Create a function to clean up the tweets and tokenize the words
token = WordPunctTokenizer()
def cleaning_tweets(t):
    del_amp = BeautifulSoup(t, 'lxml')
    del_amp_text = del_amp.get_text()
    del_link_mentions = re.sub(combined_re, '', del_amp_text)
    del_emoticons = re.sub(regex_pattern, '', del_link_mentions)
    lower_case = del_emoticons.lower()
    words = token.tokenize(lower_case)
    result_words = [x for x in words if len(x) > 2]
    return (" ".join(result_words)).strip()

# %%
# run the function on the tweets to clean it up. 
print("Cleaning the tweets...\n")
cleaned_tweets = []
for i in range(0,2000): #3000 columns in our dataframe
    if( (i+1)%100 == 0 ):
        print("Tweets {} of {} have ben processed".format(i+1,2000))                                                                  
    cleaned_tweets.append(cleaning_tweets((df.Text[i])))
# Out:
# Cleaning the tweets...
#
# Tweets 100 of 2000 have ben processed
# Tweets 200 of 2000 have ben processed
# Tweets 300 of 2000 have ben processed
# Tweets 400 of 2000 have ben processed
# Tweets 500 of 2000 have ben processed
# Tweets 600 of 2000 have ben processed
# Tweets 700 of 2000 have ben processed
# Tweets 800 of 2000 have ben processed
# Tweets 900 of 2000 have ben processed
# Tweets 1000 of 2000 have ben processed
# Tweets 1100 of 2000 have ben processed
# Tweets 1200 of 2000 have ben processed
# Tweets 1300 of 2000 have ben processed
# Tweets 1400 of 2000 have ben processed
# Tweets 1500 of 2000 have ben processed
# Tweets 1600 of 2000 have ben processed
# Tweets 1700 of 2000 have ben processed
# Tweets 1800 of 2000 have ben processed
# Tweets 1900 of 2000 have ben processed
# Tweets 2000 of 2000 have ben processed

# %%
# put the data in one string for wordcloud creation
string = pd.Series(cleaned_tweets).str.cat(sep=' ')

# %%
#get rid of the stopwords to clean up the wordcloud
stopwords = set(STOPWORDS)
stopwords.update(["https", "improveyourlovelifein5words"])

# %%
# plot the wordcloud
wordcloud = WordCloud(width=1600, stopwords=stopwords,height=800,max_font_size=200,max_words=50,collocations=False, background_color='black').generate(string)
plt.figure(figsize=(40,30))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Tweet Freq Count by Time

# %%
#put the data in a df
df2 = pd.read_json('bball_mm2.txt')
print(df2['created_at'].max())
print(df2['created_at'].min())
# Out:
# 2017-03-27 22:30:30+00:00
# 2017-03-27 20:48:07+00:00

# %%
#plot the time series data in bins using the grouper function
tweet_df_5min = df2.groupby(pd.Grouper(key='created_at', freq='T', convention='start')).size()
tweet_df_5min.plot(figsize=(18,6))
plt.ylabel('1 Minute Tweet Count')
plt.title('#MarchMadness Tweet Freq. Count, March 27th 2017')
plt.grid(True)

# %% [markdown]
# ### Top followers & friends by User

# %%
#create list for dataframe creation
tweet_user_friends = [x['user']['friends_count'] for x in data]
tweet_user_followers = [x['user']['followers_count'] for x in data]
tweet_user_name = [x['user']['name'] for x in data]
tweet_user_created_at = [x['user']['created_at'] for x in data]

# %%
# put the list in a df
df3 = pd.DataFrame(list(zip(tweet_user_friends, tweet_user_followers, tweet_user_name, tweet_user_created_at)),
                  columns = ['friends_count', 'followers_count', 'username', 'un_created_at'])

# %%
# Sory by multiple columns
df3_sorted = df3.sort_values(by=['friends_count','followers_count'], ascending=False)

# %%
df3_sorted.head()
# Out:
#       friends_count  followers_count            username  \
# 852          831550          1067910        Producer 9-0
# 1815         266021           860166   Social Stocks Now
# 1479         248371           688738    Social Start Now
# 1549         143898           156490          SNFB, Inc.
# 27            93320           195833  Author Lee Jackson
#
#                        un_created_at
# 852   Tue Oct 13 02:47:15 +0000 2009
# 1815  Mon Jun 18 14:48:03 +0000 2012
# 1479  Fri Mar 06 15:45:24 +0000 2015
# 1549  Thu Dec 03 16:56:47 +0000 2015
# 27    Wed Oct 17 01:24:55 +0000 2012

# %% [markdown]
# ### Username Wordcloud

# %%
username_wc_un = pd.DataFrame(tweet_user_name,columns=['Text'])

# %%
username_wc_un.head()
# Out:
#               Text
# 0             Will
# 1  Kahlen Donatell
# 2            Jesús
# 3            plug,
# 4   Joni Dickerson

# %%
print("Cleaning the usernames...\n")
cleaned_tweets = []
for i in range(0,2000): #2000 columns in our dataframe
    if( (i+1)%100 == 0 ):
        print("Tweets {} of {} have ben processed".format(i+1,2000))                                                                  
    cleaned_tweets.append(cleaning_tweets((username_wc_un.Text[i])))
# Out:
# Cleaning the usernames...
#
# Tweets 100 of 2000 have ben processed
# C:\Users\jncon\anaconda3\lib\site-packages\bs4\__init__.py:337: MarkupResemblesLocatorWarning: "." looks like a directory name, not markup. You may want to open a file found in this directory and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Tweets 200 of 2000 have ben processed
# Tweets 300 of 2000 have ben processed
# Tweets 400 of 2000 have ben processed
# Tweets 500 of 2000 have ben processed
# Tweets 600 of 2000 have ben processed
# Tweets 700 of 2000 have ben processed
# Tweets 800 of 2000 have ben processed
# Tweets 900 of 2000 have ben processed
# Tweets 1000 of 2000 have ben processed
# Tweets 1100 of 2000 have ben processed
# Tweets 1200 of 2000 have ben processed
# Tweets 1300 of 2000 have ben processed
# Tweets 1400 of 2000 have ben processed
# Tweets 1500 of 2000 have ben processed
# Tweets 1600 of 2000 have ben processed
# Tweets 1700 of 2000 have ben processed
# ...

# %%
string = pd.Series(cleaned_tweets).str.cat(sep=' ')

# %%
wordcloud = WordCloud(width=1600, stopwords=stopwords,height=800,max_font_size=200,max_words=50,collocations=False, background_color='black').generate(string)
plt.figure(figsize=(40,30))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Screen name WordCloud

# %%
tweet_screen_name = [x['user']['screen_name'] for x in data]

# %%
screenname_wc_un = pd.DataFrame(tweet_screen_name,columns=['Text'])

# %%
screenname_wc_un.head()
# Out:
#             Text
# 0  frenchythe1st
# 1         KahDon
# 2   _jonwilliams
# 3      21shawtyy
# 4  jonidickerson

# %%
print("Cleaning the screennames...\n")
cleaned_tweets = []
for i in range(0,2000): #2000 columns in our dataframe
    if( (i+1)%100 == 0 ):
        print("Tweets {} of {} have ben processed".format(i+1,2000))                                                                  
    cleaned_tweets.append(cleaning_tweets((screenname_wc_un.Text[i])))
# Out:
# Cleaning the screennames...
#
# Tweets 100 of 2000 have ben processed
# Tweets 200 of 2000 have ben processed
# Tweets 300 of 2000 have ben processed
# Tweets 400 of 2000 have ben processed
# Tweets 500 of 2000 have ben processed
# Tweets 600 of 2000 have ben processed
# Tweets 700 of 2000 have ben processed
# Tweets 800 of 2000 have ben processed
# Tweets 900 of 2000 have ben processed
# Tweets 1000 of 2000 have ben processed
# Tweets 1100 of 2000 have ben processed
# Tweets 1200 of 2000 have ben processed
# Tweets 1300 of 2000 have ben processed
# Tweets 1400 of 2000 have ben processed
# Tweets 1500 of 2000 have ben processed
# Tweets 1600 of 2000 have ben processed
# Tweets 1700 of 2000 have ben processed
# Tweets 1800 of 2000 have ben processed
# Tweets 1900 of 2000 have ben processed
# Tweets 2000 of 2000 have ben processed

# %%
string = pd.Series(cleaned_tweets).str.cat(sep=' ')

# %%
wordcloud = WordCloud(width=1600, stopwords=stopwords,height=800,max_font_size=200,max_words=50,collocations=False, background_color='black').generate(string)
plt.figure(figsize=(40,30))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Most popular OS for Tweets

# %%
tweet_source = [x['source'] for x in data]

# %%
source_count = pd.DataFrame(tweet_source,columns=['Text'])

# %%
source_count.head()
# Out:
#                                                 Text
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...

# %%
# extract the operating system using regex
source_count['NewCol'] = source_count['Text'].str.extract(r'>(.{1,20})<\/a>', expand=False)

# %%
source_count.head()
# Out:
#                                                 Text              NewCol
# 0  <a href="http://twitter.com/download/iphone" r...  Twitter for iPhone
# 1  <a href="http://twitter.com/download/iphone" r...  Twitter for iPhone
# 2  <a href="http://twitter.com/download/iphone" r...  Twitter for iPhone
# 3  <a href="http://twitter.com/download/iphone" r...  Twitter for iPhone
# 4  <a href="http://twitter.com/download/iphone" r...  Twitter for iPhone

# %%
#plot the most popular operating systems using value_counts()
source_count['NewCol'].value_counts()[:10].plot(kind='barh')
# Out:
# <AxesSubplot:>
